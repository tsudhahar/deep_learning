# %%
#!/usr/bin/env python
# %matplotlib inline
import logging
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import pickle
import random
import math
import itertools
from keras.layers import GlobalAveragePooling2D,Flatten
from keras.layers import Dense,Input,Lambda,concatenate,BatchNormalization,Dropout,Activation
from keras.models import Sequential, Model
from keras.optimizers import SGD,Adam
from sklearn.decomposition import PCA,IncrementalPCA
from sklearn.neighbors import KNeighborsClassifier
from keras.callbacks import EarlyStopping,Callback,TensorBoard,LearningRateScheduler
from keras import backend as K
from keras.initializers import TruncatedNormal
from keras.regularizers import l2,l1,l1_l2
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import precision_score, recall_score,accuracy_score
import tensorflow as tf
import bob.measure
# Out:
# /Users/gltest/anaconda3/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# %%
batch_num =  128
embedding_num  = 32
alpha = 0.2

# %%
def triplet_loss(y_true, y_pred):
    """
    :param y_true:
    :param y_pred:
    :return: triplet loss
    """
    # L= ||anchor_embedding - positive_embedding||  + alpha - ||anchor_embedding - negative_embedding||

    anchor, pos, neg = y_pred[:,0:embedding_num],y_pred[:,embedding_num:2*embedding_num],y_pred[:,2*embedding_num:3*embedding_num]
    dist_pos = K.sum(K.square(anchor - pos), axis=-1)
    dist_neg = K.sum(K.square(anchor - neg), axis=-1)
    margin = K.constant(alpha)
    return K.mean(K.sum((K.maximum(0.0,dist_pos-dist_neg+margin) )))


def accuracy(y_true, y_pred):
    """
    :param y_true:
    :param y_pred:
    :return: percentage of triplets satisfying  ||anchor_embedding - positive_embedding|| + alpha<||anchor_embedding - negative_embedding||
    """
    anchor, pos, neg = y_pred[:, 0:embedding_num], y_pred[:, embedding_num:2 * embedding_num], y_pred[:,2 * embedding_num:3 * embedding_num]
    dist_pos = K.sum(K.square(anchor - pos), axis=1)
    dist_neg = K.sum(K.square(anchor - neg), axis=1)
    margin = K.constant(alpha)
    return K.sum(K.cast(K.less(dist_pos+ margin ,dist_neg),dtype='int32'))/K.shape(y_pred)[0]

def l2_distance (anchor, query):
    """
    l2 distance between anchor and query embeddings
    :param anchor:
    :param query:
    :return:
    """
    return np.sum(np.square(anchor - query),axis=1)

def l2_similarity(query_embedding,label_embedings):
    """

    :param query_embedding:
    :param labels_embedings:
    :return:  l2 similarity and idics array of the closet identities label_embbedings toward query's embeddings
    """
    dist = np.zeros(len(label_embedings))
    dist = l2_distance(query_embedding, label_embedings)
    sorted_idcs = sorted(range(len(dist)), key=lambda k: dist[k])
    similarity = dist[sorted_idcs]
    return similarity, np.array(sorted_idcs)

# %%
def query_top_match(query_embedding,anchor_embedings,anchor_labels, thres, top_k=5):
    """return top match at threshold
    :param query_embedding:
    :param labels_embedings:
    :param anchor_labels:
    :paran anchor_thres;:
    :param top_num: top k matches
    :return: matching labels top_k matches at threshold
    """
    dist, idcs = l2_similarity(query_embedding,anchor_embedings)

    dist_top_k_idcs = np.where(dist < thres)[0][0:top_k]

    if np.asarray(dist_top_k_idcs).size >0:
        dist_top_k_labels = anchor_labels[idcs[dist_top_k_idcs]]
        unique_labels,first_idcs, counts = np.unique(dist_top_k_labels, return_counts=True,return_index=True)
        match_idx = np.where(counts==counts.max())

        if np.asarray(match_idx).size >=2:  # tied match
            # the first occuring one in the top_k
            match_idx = np.argsort(first_idcs[match_idx])
            match = unique_labels[match_idx[0]]
        else:
            match = unique_labels[match_idx]
        match = np.asscalar(match)  # convert 1x1 array to a numbers
        return match
    else:
        return []

# %%
def generate_anchor_positive(ids,batch_num=128):
    """
    :param ids: index array of the same identity
    :return: all pairs of [anchor, positive]. position matters
    """
    if len(ids) < 2 :
        #print("number of picture less than 2")
        return []
    results = []
    datasets = set()
    datasets.add(ids[0])
    datasets.add(ids[1])
    results.append(np.array([ids[0], ids[1]]))
    results.append(np.array([ids[1], ids[0]]))
    for idx in range(2, len(ids)):
        for elem in datasets:
            results.append(np.array([ids[idx], elem]))
            results.append(np.array([elem, ids[idx]]))
        datasets.add(ids[idx])
    results = np.array(results)
    if batch_num != None:
        if len(results) < batch_num:
            #copy itself to fill to the batch_num
            list = np.random.choice(len(results), batch_num-len(results))
            results = np.vstack( (results, results[list]))
        else:
            list = np.random.choice(len(results),batch_num)
            results = results[list]
    return results

def get_unique_labels(labels):
    """

    :param labels: unique labels preserving orders from the label array
    :return:
    """
    _, idx = np.unique(labels, axis=0, return_index=True)
    return labels[np.sort(idx)]

# %%
class EmbeddingUpdator(Callback):
    "Keras Callback implemenation of saving the model and update embeddings"
    def __init__(self, filepath,  train_codes, train_labels, data_dir, monitor='val_loss',verbose=0,
                 save_best_only=False, save_weights_only=False,
                 mode='auto', period=1 ):
        super(EmbeddingUpdator, self).__init__()
        self.monitor = monitor
        self.verbose = verbose
        self.filepath = filepath
        self.save_best_only = save_best_only
        self.save_weights_only = save_weights_only
        self.period = period
        self.epochs_since_last_save = 0
        self.train_codes = train_codes
        self.train_labels = train_labels
        self.data_dir = data_dir

        if mode not in ['auto', 'min', 'max']:
            logger.warn('ModelCheckpoint mode %s is unknown, '
                          'fallback to auto mode.' % (mode),
                          RuntimeWarning)
            mode = 'auto'

        if mode == 'min':
            self.monitor_op = np.less
            self.best = np.Inf
        elif mode == 'max':
            self.monitor_op = np.greater
            self.best = -np.Inf
        else:
            if 'acc' in self.monitor or self.monitor.startswith('fmeasure'):
                self.monitor_op = np.greater
                self.best = -np.Inf
            else:
                self.monitor_op = np.less
                self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        self.epochs_since_last_save += 1
        if self.epochs_since_last_save >= self.period:
            self.epochs_since_last_save = 0
            filepath = self.filepath.format(epoch=epoch, **logs)
            if self.save_best_only:
                current = logs.get(self.monitor)
                if current is None:
                    logger.warn('Can save best model only with %s available, '
                                  'skipping.' % (self.monitor), RuntimeWarning)
                else:
                    if self.monitor_op(current, self.best):
                        if self.verbose > 0:
                            print('Epoch %05d: %s improved from %0.5f to %0.5f,'
                                  ' saving model to %s'
                                  % (epoch, self.monitor, self.best,
                                     current, filepath))
                        self.best = current
                        if self.save_weights_only:
                            self.model.save_weights(filepath, overwrite=True)
                        else:
                            self.model.save(filepath, overwrite=True)

                        # update the embedding
                        output = self.model.predict([self.train_codes,self.train_codes,self.train_codes],batch_size = 128)
                        embeddings = output[:,0:embedding_num]

                        file_name = os.path.join(self.data_dir, 'embeddings.npy')
                        np.save(open(file_name, 'wb'),embeddings)
                        # for i in range(len(embeddings)):
                        #     print(embeddings[i])
                        print("Embeddings updated")

                    else:
                        if self.verbose > 0:
                            print('Epoch %05d: %s did not improve' %
                                  (epoch, self.monitor))
            else:
                if self.verbose > 0:
                    print('Epoch %05d: saving model to %s' % (epoch, filepath))
                if self.save_weights_only:
                    self.model.save_weights(filepath, overwrite=True)
                else:
                    self.model.save(filepath, overwrite=True)

# %%
class tripletDataGenerator(object):
    "data generator for keras"
    def __init__(self,batch_size, classifier_filename,data_dir, shuffle = False):
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.classifier_filename = classifier_filename
        self.data_dir = data_dir
        self.num_N = 32
        self.num_P = 32

    def generate(self, train_codes, train_labels,embedding_layer):
        "generate batch of sample"
        x_codes = train_codes
        labels = train_labels
        while True:
            file_name = os.path.join(self.data_dir, 'embeddings.npy')
            embeddings = np.load(file_name)

            print("embeddings loaded")
            if embeddings is None or len(embeddings)< 1:
                print("embeddings empty!")
                continue
            elif np.all(embeddings==0):
                print("embeddings collaps!")


            if self.shuffle == True:
                indics = np.arange(len(train_labels))
                np.random.shuffle(indics)
                x_codes = train_codes[indics]

                labels = train_labels[indics]
                embeddings = embeddings[indics]

            yield_idx = 0
            batch_num = self.batch_size

            step = 0
            while (step < len(labels)//self.batch_size):

                batch_idics = np.arange(batch_num*step,batch_num*(step+1))
                batch_codes = x_codes[batch_idics]
                batch_labels = labels[batch_idics]
                batch_embeddings = embeddings[batch_idics]
                #print("unique label length:", len(np.unique(batch_labels)))
                triplets = []
                for y in np.unique(batch_labels):
                    pos_ids = np.asarray(np.where((batch_labels == y)))[0]
                    if len(pos_ids) < 2:
                        continue
                    pos_P_idcs =  np.random.choice(len(pos_ids),  min(len(pos_ids),self.num_P))
                    pos_ids = pos_ids[pos_P_idcs]    
                    all_pos_embeddings = batch_embeddings[pos_ids] 
                    ng_idcs, =np.where((batch_labels!=y))
                    if len(ng_idcs) < 1:
                        continue
                    #sample at the most num_N
                    pos_N_idcs =  np.random.choice(len(ng_idcs),  min(len(ng_idcs),self.num_N))
                    ng_idcs = ng_idcs[pos_N_idcs]
                    all_ng_embeddings = batch_embeddings[ng_idcs]
                    # sorted_dist_neg, sorted_neg_idx = l2_similarity(batch_embeddings[pos_ids[0]], all_ng_embeddings)
                    #triplets = []
                    for a in range(len(pos_ids)):
                        sorted_dist_pos, sorted_pos_idx = l2_similarity(batch_embeddings[pos_ids[a]], all_pos_embeddings)
                        #the hardest <anchor, positive> and the hardest <anchor, negative>
                        if sorted_dist_pos[-1] > 0 :
                            max_pos_idx = pos_ids[sorted_pos_idx[-1]]
                        else:
                            continue  
                        sorted_dist_neg, sorted_neg_idx = l2_similarity(batch_embeddings[pos_ids[a]], all_ng_embeddings)
                        min_neg_idx = ng_idcs[sorted_neg_idx[0]]
                        triplets.append(np.array([pos_ids[a]+batch_num*step , max_pos_idx + batch_num*step, min_neg_idx+batch_num*step]))

                if len(triplets) > 0:
                    # randomize
                    triplets = np.array(triplets)
                    indics = np.arange(len(triplets))
                    np.random.shuffle(indics)
                    triplets = triplets[indics]
                    #print("length of triplets:", len(triplets))
                    yield [x_codes[triplets[:, 0]], x_codes[triplets[:, 1]], x_codes[triplets[:, 2]]], np.ones(len(triplets))
                step +=1


            # the last batch incomplete
            if len(labels) -batch_num*step> 0:
                triplets = []
                batch_idics = np.arange(batch_num*step,len(labels))
                batch_codes = x_codes[batch_idics]
                batch_labels = labels[batch_idics]
                batch_embeddings = embeddings[batch_idics]
                #print("unique label length:", len(np.unique(batch_labels)))
                for y in np.unique(batch_labels):
                    #triplets = []
                    pos_ids = np.asarray(np.where((batch_labels == y)))[0]
                    if len(pos_ids) < 2:
                        continue
                    pos_P_idcs =  np.random.choice(len(pos_ids),  min(len(pos_ids),self.num_P))
                    pos_ids = pos_ids[pos_P_idcs]  
                    all_pos_embeddings = batch_embeddings[pos_ids]
                    ng_idcs, =np.where((batch_labels!=y))
                    if len(ng_idcs) < 1:
                        continue
                    #sample at the most num_N
                    pos_N_idcs =  np.random.choice(len(ng_idcs),  min(len(ng_idcs),self.num_N))
                    ng_idcs = ng_idcs[pos_N_idcs]
                    all_ng_embeddings = batch_embeddings[ng_idcs]
                    # sorted_dist_neg, sorted_neg_idx = l2_similarity(batch_embeddings[pos_ids[0]], all_ng_embeddings)

                    for a in range(len(pos_ids)):
                        sorted_dist_pos, sorted_pos_idx = l2_similarity(batch_embeddings[pos_ids[a]], all_pos_embeddings)
                        #the hardest <anchor, positive> and the hardest <anchor, negative>
                        if sorted_dist_pos[-1] > 0 :
                            max_pos_idx = pos_ids[sorted_pos_idx[-1]]
                        else:
                            continue  
                        sorted_dist_neg, sorted_neg_idx = l2_similarity(batch_embeddings[pos_ids[a]], all_ng_embeddings)
                        min_neg_idx = ng_idcs[sorted_neg_idx[0]]
                        triplets.append(np.array([pos_ids[a]+batch_num*step , max_pos_idx + batch_num*step, min_neg_idx+batch_num*step]))

                if len(triplets) > 0:
                    # randomize
                    triplets = np.array(triplets)
                    indics = np.arange(len(triplets))
                    np.random.shuffle(indics)
                    triplets = triplets[indics]
                    yield [x_codes[triplets[:, 0]], x_codes[triplets[:, 1]], x_codes[triplets[:, 2]]], np.ones(len(triplets))

# %%
class tripletValidationDataGenerator(object):
    "data generator for keras"
    def __init__(self,batch_size, shuffle = False):
        self.batch_size = batch_size
        self.shuffle = shuffle
    
    def generate(self, val_codes,val_labels):
        "generate batch of sample"
        #unique_labels = get_unique_labels(labels)
        codes = val_codes
        labels = val_labels

        while True:
            if self.shuffle == True:
                indics = np.arange(len(val_labels))
                np.random.shuffle(indics)
                codes = val_codes[indics]
                labels = val_labels[indics]
            #print("val_labels:",labels)
            step = 0
            while (step < len(labels)//self.batch_size):
                batch_idics = np.arange(self.batch_size*step,self.batch_size*(step+1))
                batch_codes = codes[batch_idics]
                batch_labels = labels[batch_idics]
                unique_batch_labels = get_unique_labels(batch_labels)
                for y in unique_batch_labels:                
                    pos_ids = np.asarray(np.where((batch_labels == y)))[0]
                    if len(pos_ids) < 2:
                        continue
                    ng_idcs, =np.where((batch_labels!=y))
                    if len(ng_idcs) < 1:
                        continue    

                    ap_pair = generate_anchor_positive(pos_ids, batch_num=len(ng_idcs))
                    yield [batch_codes[ap_pair[:, 0]], batch_codes[ap_pair[:, 1]], batch_codes[ng_idcs]], np.ones(len(ap_pair))
                step +=1

            # the last batch incomplete

            if len(labels) - self.batch_size*step> 0:
                batch_idics = np.arange(self.batch_size*step,len(labels))
                batch_codes = codes[batch_idics]
                batch_labels = labels[batch_idics]
                unique_batch_labels = get_unique_labels(batch_labels)
                for y in unique_batch_labels:
                    pos_ids = np.asarray(np.where((batch_labels == y)))[0]
                    #print("y: ",y, pos_ids)
                    if len(pos_ids) < 2:
                        continue
                    ng_idcs, =np.where((batch_labels!=y))
                    if len(ng_idcs) < 1:
                        continue    

                    ap_pair = generate_anchor_positive(pos_ids, batch_num=len(ng_idcs) )
                    yield [batch_codes[ap_pair[:, 0]], batch_codes[ap_pair[:, 1]], batch_codes[ng_idcs]], np.ones(len(ap_pair))

# %%
class TripletClassifier():
    def __init__(self, classfier_filename, data_dir, num_embeddings):
        self.classifier_filename = classfier_filename
        self.num_embeddings = num_embeddings
        self.alpha = 0.2
        self.thres = 1.0
        self.data_dir = data_dir
        K.set_image_data_format('channels_last')


    def prepare(self):
        self.train_codes = np.load(os.path.join(self.data_dir, 'train_codes.npy'))
        self.test_codes = np.load(os.path.join(self.data_dir, 'test_codes.npy'))
        self.train_labels = np.squeeze(np.load(os.path.join(self.data_dir, 'train_labels.npy')))
        self.test_labels = np.squeeze(np.load(os.path.join(self.data_dir, 'test_labels.npy')))
        self.test_idcs = np.load(os.path.join(self.data_dir,'test_labels_idcs.npy'))
        self.random_draw_codes = np.load(os.path.join(self.data_dir, 'random_draw_codes.npy'))
        self.random_draw_label = np.squeeze(np.load(os.path.join(self.data_dir, 'random_draw_labels.npy')))

        ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)
        train_idcs, val_idcs = next(ss.split(self.train_codes, self.train_labels))
        self.x_codes = self.train_codes[train_idcs]
        self.y_labels = self.train_labels[train_idcs]
        self.val_codes = self.train_codes[val_idcs]
        self.val_labels = self.train_labels[val_idcs]


        # classifier
        logger.info("train codes shape {}".format(self.x_codes.shape))
        logger.info("validation codes shape {}".format(self.val_codes.shape))
        logger.info("train label shape {}".format(self.y_labels.shape))
        logger.info("validation label shape {}".format(self.val_labels.shape))
        logger.info("test codes  shape {}".format(self.test_codes.shape))
        logger.info("test labels  shape {}".format(self.test_labels.shape))

        input = Input(shape=(1, 1, 2048))
        x = Flatten(name='flatten')(input)
        x = Dense(self.num_embeddings, kernel_initializer= TruncatedNormal(stddev=0.05),
                 use_bias= False, name='embeddings', kernel_regularizer=l2(0.001))(x)
        x = Lambda(lambda  x: K.l2_normalize(x,axis=1))(x)

        branch = Model(inputs=input,outputs=x)

        anchors = Input(shape=(1, 1, 2048))
        positives = Input(shape=(1, 1, 2048))
        negatives = Input(shape=(1, 1, 2048))

        anchors_embeddings = branch(anchors)
        positives_embeddings = branch(positives)
        negatives_embeddings = branch(negatives)
        merged = concatenate([anchors_embeddings, positives_embeddings,negatives_embeddings],axis=1)

        self.model = Model([anchors, positives,negatives], merged)
        self.model.compile(loss= triplet_loss,
                           optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08),
                            metrics=[accuracy])
        self.model.summary()

    def train(self):

        ## split training set further for training and validation set

        start_time = time.time()
        # initial embedding. The average of all training data.
        pca = PCA(n_components=embedding_num)
        temp = np.array(self.x_codes).reshape((self.x_codes.shape[0],-1))
        g_embeddings = pca.fit_transform(temp)

        file_name = os.path.join(self.data_dir, 'embeddings.npy')
        np.save(open(file_name, 'wb'),g_embeddings)
        print("Embeddings updated")

        logger.info('Training starts...' )
        checkpointer = EmbeddingUpdator(filepath=self.classifier_filename,train_codes=self.x_codes, train_labels = self.y_labels , data_dir = self.data_dir,
                monitor ='val_loss', verbose=1, save_best_only=True)
        #early_stopping = EarlyStopping(monitor='val_loss',patience=20)
        tbCallBack = TensorBoard(log_dir='./logs',batch_size= batch_num, histogram_freq=0, write_graph=True,
                                                 write_images=True, write_grads = True)
        tbCallBack.set_model(self.model)

        train_data_params = {
            'batch_size':batch_num,
            'shuffle':True,
            'classifier_filename': self.classifier_filename,
            'data_dir':self.data_dir
        }
        val_batch_size = 64
        val_data_params = {
            'batch_size':val_batch_size,
            'shuffle':True
        }
        train_data_generator = tripletDataGenerator(**train_data_params).generate(self.x_codes,self.y_labels,self.model)
        val_data_generator = tripletValidationDataGenerator (**val_data_params).generate(self.val_codes,self.val_labels)

        evaluation = self.model.fit_generator(train_data_generator,
                        steps_per_epoch=(len(self.y_labels)+ batch_num-1) // batch_num,
                        epochs=1000,
                        verbose=1,
                        callbacks=[checkpointer,tbCallBack],
                        validation_data=val_data_generator,
                        validation_steps = (val_batch_size * len(np.unique(self.val_labels))+ batch_num-1)//batch_num,
                        use_multiprocessing = False)

        logger.info('Completed in {} seconds'.format(time.time() - start_time))
        logger.info("Training result {}".format(evaluation))
        pickle.dump(evaluation.history, open("../model/triplet_train_history.pickle", "wb"))

        return 0

    def train_history_visual(self):

        # summarize history for accuracy
        with open("../model/triplet_train_history.pickle", 'rb') as pickle_file:
            history = pickle.load(pickle_file)
        plt.figure(figsize=(8,4))

        plt.subplot(1, 2, 1)
        plt.plot(history['accuracy'])
        plt.plot(history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'val'], loc='lower right')
        axes = plt.gca()
        axes.set_ylim([0.0, 1.05])

        plt.subplot(1, 2, 2)
        plt.plot(history['loss'])
        plt.plot(history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'val'], loc='upper right')

        plt.show()

    def predict(self, test_codes, anchor_embeddings,anchor_labels, anchor_thres,top_k = 5):
        test_embeddings = self.model.predict([test_codes,test_codes,test_codes],batch_size = 128)
        test_embeddings = test_embeddings[:,0:embedding_num]
        match_labels_thres = []

        for query_embedding in test_embeddings:
            dist = l2_distance(query_embedding[None, :], anchor_embeddings)
            sorted_idcs = np.array(sorted(range(len(dist)), key=lambda k: dist[k]))
            top_k_idcs = sorted_idcs[:top_k]
            top_k_match = []
            for cand in top_k_idcs:
                if dist[cand] < anchor_thres[cand]:
                    top_k_match.append(anchor_labels[cand])
            if len(top_k_match )>0:
                unique_labels,first_idcs, counts = np.unique(np.array(top_k_match), return_counts=True,return_index=True)
                if len(unique_labels) >0 :
                    match_idx = np.where(counts==counts.max())
                    if  np.asarray(match_idx).size >=2:  #tied match
                        # the first occuring one in the top_k . It has the smallest distance
                        match_idx = np.argsort(first_idcs[match_idx])
                        match = unique_labels[match_idx[0]]
                        match = np.ravel(match)
                    else:
                        match = unique_labels[match_idx]
                    match_labels_thres.append(np.asscalar(match))
            else:
                match_labels_thres.append(-1)

        return match_labels_thres

    def generate_labels_embeddings_threshold(self):
        self.model.load_weights(self.classifier_filename)
        embeddings = self.model.predict([self.val_codes, self.val_codes, self.val_codes],batch_size = 128)
        y_labels = self.val_labels
        embeddings = embeddings[:,0:embedding_num]
        label_embeddings = []
        label_thres = []
        labels = []
        num_N = 128
        for id in np.unique(y_labels):
            same_labels_ids = np.where(y_labels == id )[0]
            ng_labels_ids = np.where(y_labels !=id )[0]
            pos_dist = []
            neg_dist = []
            label_embeddings.append(embeddings[same_labels_ids].mean(axis=0))

            for i,j in itertools.combinations(same_labels_ids,2):
                pos_dist.append(l2_distance(embeddings[i][None,:], embeddings[j][None,:]))

            for i in same_labels_ids:
                for j in ng_labels_ids:
                    neg_dist.append(l2_distance(embeddings[i][None,:], embeddings[j][None,:]))
            pos_dist = np.array(pos_dist,dtype='double').ravel()
            neg_dist = np.array(neg_dist,dtype='double').ravel()
            label_thres.append(neg_dist.min())
            labels.append(id)
        label_embeddings = np.vstack(label_embeddings)

        return label_embeddings,labels,np.array(label_thres)

    def evaluate(self):
        true_accept = 0.0
        false_accept = 0.0
        true_reject = 0.0
        false_reject = 0.0

        anchor_embeddings, anchor_labels, anchor_thres = self.generate_labels_embeddings_threshold()
        logger.info("Distance threshold {0:.4f}:".format(np.mean(anchor_thres)) )

        logger.info("Testing all authorized labels...")
        predictions_thres = self.predict(self.test_codes,anchor_embeddings,anchor_labels, anchor_thres,top_k=5)

        all_test = 0.0

        for test_id in range(len(self.test_labels)):
            if np.asarray(np.where(predictions_thres[test_id] == self.test_labels[test_id])).size==0:
                logger.info("data id  {} false rejected as label {}, true label {}"
                            .format(self.test_idcs[test_id],predictions_thres[test_id],self.test_labels[test_id]))
                false_reject += 1.0

            else:
                true_accept += 1.0
            all_test += 1.0

        TR = true_accept/all_test
        FR = false_reject/all_test

        logger.info("true_acceptance: {0:.4f}".format(TR))
        logger.info("false_rejection: {0:.4f}".format(FR))

        logger.info("Testing random draw labels...")

        predictions_thres = self.predict(self.random_draw_codes,anchor_embeddings,anchor_labels, anchor_thres,top_k=5)
        # what went wrong
        true_accept = 0.0
        false_accept = 0.0
        true_reject = 0.0
        false_reject = 0.0
        all_test = 0.0
        for test_id in range(len(self.random_draw_codes)):
            all_test += 1 
            if (self.random_draw_label[test_id]== self.train_labels).any() == True:
                # in the system
                if np.asarray(predictions_thres[test_id]).size == 0 or predictions_thres[test_id] != self.random_draw_label[test_id]:
                    false_reject += 1.0
                    logger.info("data id  {} false rejected as label {}, true label {}"
                                .format(test_id, predictions_thres[test_id], self.random_draw_label[test_id]))
                else:
                    true_accept += 1.0
                    logger.info("data id  {} accepted label  {} true label {} "
                                .format(test_id, predictions_thres[test_id],self.random_draw_label[test_id] ))
            else:
                # not in the system
                if predictions_thres[test_id]!= -1:
                    false_accept += 1.0
                    logger.info("data id  {} false accepted as label {}, none autherized label {}"
                                .format(test_id, predictions_thres[test_id], self.random_draw_label[test_id]))

                else:
                    true_reject += 1.0
                    logger.info("data id  {} rejected label {}, none autherized"
                                .format(test_id, self.random_draw_label[test_id]))


        FAR = false_accept / all_test
        TR = true_reject/all_test
        logger.info("true_rejection: {0:.4f}".format(TR))
        logger.info("false_acceptance: {0:.4f}".format(FAR))

    def Alejandro_Toledo_match_visual(self):
        # its label is 128
        Alejandro_Toledo_idcs = np.where(self.test_labels == 128)[0]

        df = pd.read_csv(os.path.join(self.data_dir,"lfw_dataset.csv"),names=['id','label','name','path'])
        predicted_name = []
        predicted_image_path = []
        true_image_path = []
        
        anchor_embeddings, anchor_labels, anchor_thres = self.generate_labels_embeddings_threshold()
        
        for i in range(len(Alejandro_Toledo_idcs)):
            test_codes = self.test_codes[Alejandro_Toledo_idcs[i]]
            predicted_label = self.predict(test_codes[None,:],anchor_embeddings,anchor_labels, anchor_thres,top_k=5)[0]
            data_id = self.test_idcs[Alejandro_Toledo_idcs[i]]

            if predicted_label != 128 and  predicted_label != -1 :
                predicted_name.append(df[df['label']== str(predicted_label)]['name'].values[0])
                true_image_path.append(df.iloc[data_id]['path'].strip())
                predicted_image_path.append(df[df['label']== str(predicted_label)]['path'].values[0])

        fig = plt.figure(figsize=(8, 6))
        for i in range(len(predicted_image_path)):
            ax = fig.add_subplot(len(predicted_image_path),2, 2*i + 1, xticks=[], yticks=[])
            img = mpimg.imread(true_image_path[i].strip())
            ax.imshow(img)
            ax = fig.add_subplot(len(predicted_image_path),2, 2*i + 2, xticks=[], yticks=[])
            img = mpimg.imread(predicted_image_path[i].strip())
            ax.imshow(img)
            ax.set_title("predicted as {}".format(predicted_name[i]),
                color=("green" if predicted_name[i] == 'Alejandro_Toledo' else "red")) 
        plt.show()

    def GW_Bush_Distance_visual(self):
        # to see how close each picture's embedding is
        # its label is 1872
        GW_Bush_idcs = np.where(self.test_labels == 1872)[0]

        GW_Bush_embeddings = self.model.predict([self.test_codes[GW_Bush_idcs],self.test_codes[GW_Bush_idcs],self.test_codes[GW_Bush_idcs]],batch_size = 128)
        GW_Bush_embeddings = GW_Bush_embeddings[:,0:embedding_num]

        df = pd.read_csv(os.path.join(self.data_dir,"lfw_dataset.csv"),names=['id','label','name','path'],header = None)
        
        GW_Bush_anchor = GW_Bush_embeddings[0]
        dist = l2_distance(GW_Bush_anchor[None,:], GW_Bush_embeddings)

        fig = plt.figure(figsize=(15, 25))
        for i in range(len(GW_Bush_idcs)):
            data_id = self.test_idcs[GW_Bush_idcs[i]]
            ax = fig.add_subplot(len(GW_Bush_idcs),3, i + 1, xticks=[], yticks=[])
            img = mpimg.imread(df.iloc[data_id+1]['path'].strip())
            ax.imshow(img)
            ax.set_title(label = (" {0:.4f}".format(dist[i]) if i> 0 else "anchor"),color="green" ) 
        plt.show()

# %%
clr = TripletClassifier(classfier_filename='../model/weights_triplet_loss.hdf5',
                        data_dir='../data/cropped_20',num_embeddings = embedding_num)
clr.prepare()
# Out:
# INFO:__main__:train codes shape (1520, 1, 1, 2048)
# INFO:__main__:validation codes shape (381, 1, 1, 2048)
# INFO:__main__:train label shape (1520,)
# INFO:__main__:validation label shape (381,)
# INFO:__main__:test codes  shape (476, 1, 1, 2048)
# INFO:__main__:test labels  shape (476,)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 1, 1, 2048)   0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           (None, 1, 1, 2048)   0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           (None, 1, 1, 2048)   0
# __________________________________________________________________________________________________
# model_5 (Model)                 (None, 32)           65536       input_10[0][0]
#                                                                  input_11[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96)           0           model_5[1][0]
#                                                                  model_5[2][0]
#                                                                  model_5[3][0]
# ==================================================================================================
# Total params: 65,536
# Trainable params: 65,536
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
clr.train()
# Out:
# INFO:__main__:Training starts...
# Embeddings updated
# Epoch 1/1000
# embeddings loaded
# embeddings loaded
# Epoch 00000: val_loss improved from inf to 11.21869, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 39ms/step - loss: 26.2614 - accuracy: 0.0044 - val_loss: 11.2187 - val_accuracy: 0.0437
# Epoch 2/1000
#  1/12 [=>............................] - ETA: 0s - loss: 24.9929 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 24.7352 - accuracy: 0.0000e+00Epoch 00001: val_loss improved from 11.21869 to 9.95465, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 24ms/step - loss: 23.4005 - accuracy: 0.0000e+00 - val_loss: 9.9547 - val_accuracy: 0.0147
# Epoch 3/1000
#  1/12 [=>............................] - ETA: 0s - loss: 25.2466 - accuracy: 0.0000e+00embeddings loaded
#  6/12 [==============>...............] - ETA: 0s - loss: 25.3344 - accuracy: 0.0000e+00Epoch 00002: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 24.4010 - accuracy: 0.0000e+00 - val_loss: 11.3870 - val_accuracy: 0.0070
# Epoch 4/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 23.9038 - accuracy: 0.0000e+00Epoch 00003: val_loss did not improve
#  - 0s 22ms/step - loss: 23.3657 - accuracy: 0.0000e+00 - val_loss: 11.5267 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# embeddings loaded
# Epoch 00004: val_loss did not improve
# 12/12 [==============================] - 0s 17ms/step - loss: 21.9052 - accuracy: 0.0000e+00 - val_loss: 11.8996 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# embeddings loaded
# Epoch 00005: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 21.2776 - accuracy: 0.0000e+00 - val_loss: 11.9163 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# embeddings loaded
# Epoch 00006: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 21.4266 - accuracy: 0.0000e+00 - val_loss: 11.8221 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# embeddings loaded
# Epoch 00007: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 20.4036 - accuracy: 0.0000e+00 - val_loss: 11.8544 - val_accuracy: 0.0000e+00
# Epoch 9/1000
# embeddings loaded
# Epoch 00008: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 20.8755 - accuracy: 0.0000e+00 - val_loss: 12.2091 - val_accuracy: 0.0000e+00
# Epoch 10/1000
# embeddings loaded
# Epoch 00009: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 20.6982 - accuracy: 0.0000e+00 - val_loss: 11.9673 - val_accuracy: 0.0000e+00
# Epoch 11/1000
# embeddings loaded
# Epoch 00010: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 19.9956 - accuracy: 0.0000e+00 - val_loss: 12.0740 - val_accuracy: 0.0000e+00
# Epoch 12/1000
# embeddings loaded
# Epoch 00011: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 20.4631 - accuracy: 0.0000e+00 - val_loss: 12.2656 - val_accuracy: 0.0000e+00
# Epoch 13/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 20.2759 - accuracy: 0.0000e+00Epoch 00012: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 20.0585 - accuracy: 0.0000e+00 - val_loss: 12.0396 - val_accuracy: 0.0000e+00
# Epoch 14/1000
# embeddings loaded
# Epoch 00013: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 20.0496 - accuracy: 0.0000e+00 - val_loss: 12.2622 - val_accuracy: 0.0000e+00
# Epoch 15/1000
# embeddings loaded
# Epoch 00014: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 19.9875 - accuracy: 0.0000e+00 - val_loss: 12.3714 - val_accuracy: 0.0000e+00
# Epoch 16/1000
# embeddings loaded
# Epoch 00015: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 20.2368 - accuracy: 0.0000e+00 - val_loss: 12.1264 - val_accuracy: 0.0000e+00
# Epoch 17/1000
# embeddings loaded
# 10/12 [========================>.....] - ETA: 0s - loss: 20.2916 - accuracy: 0.0000e+00Epoch 00016: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 19.6430 - accuracy: 0.0000e+00 - val_loss: 12.1498 - val_accuracy: 0.0000e+00
# Epoch 18/1000
#  1/12 [=>............................] - ETA: 0s - loss: 19.2319 - accuracy: 0.0000e+00embeddings loaded
#  8/12 [===================>..........] - ETA: 0s - loss: 19.9881 - accuracy: 0.0000e+00Epoch 00017: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 19.5547 - accuracy: 0.0000e+00 - val_loss: 12.3402 - val_accuracy: 0.0000e+00
# Epoch 19/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.7640 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 19.5224 - accuracy: 0.0000e+00Epoch 00018: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 19.6635 - accuracy: 0.0000e+00 - val_loss: 12.0860 - val_accuracy: 0.0000e+00
# Epoch 20/1000
#  1/12 [=>............................] - ETA: 0s - loss: 20.8412 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 20.3121 - accuracy: 0.0000e+00Epoch 00019: val_loss did not improve
#  - 0s 18ms/step - loss: 20.0402 - accuracy: 0.0000e+00 - val_loss: 12.2648 - val_accuracy: 0.0000e+00
# Epoch 21/1000
# embeddings loaded
# Epoch 00020: val_loss did not improve
# 12/12 [==============================] - 0s 16ms/step - loss: 18.9484 - accuracy: 0.0000e+00 - val_loss: 12.3999 - val_accuracy: 0.0000e+00
# Epoch 22/1000
# embeddings loaded
# Epoch 00021: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 20.0766 - accuracy: 0.0000e+00 - val_loss: 12.0368 - val_accuracy: 0.0000e+00
# Epoch 23/1000
# embeddings loaded
# Epoch 00022: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 19.4738 - accuracy: 0.0000e+00 - val_loss: 12.3387 - val_accuracy: 0.0000e+00
# Epoch 24/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.9065 - accuracy: 0.0000e+00Epoch 00023: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 18.7886 - accuracy: 0.0000e+00 - val_loss: 12.3743 - val_accuracy: 0.0000e+00
# Epoch 25/1000
# embeddings loaded
# Epoch 00024: val_loss did not improve
# 12/12 [==============================] - 0s 16ms/step - loss: 19.6198 - accuracy: 0.0000e+00 - val_loss: 12.0298 - val_accuracy: 0.0000e+00
# Epoch 26/1000
# embeddings loaded
# Epoch 00025: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.7657 - accuracy: 0.0000e+00 - val_loss: 12.3109 - val_accuracy: 0.0000e+00
# Epoch 27/1000
# embeddings loaded
# Epoch 00026: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 18.6959 - accuracy: 0.0000e+00 - val_loss: 12.5429 - val_accuracy: 0.0000e+00
# Epoch 28/1000
# embeddings loaded
# Epoch 00027: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 19.4595 - accuracy: 0.0000e+00 - val_loss: 12.2038 - val_accuracy: 0.0000e+00
# Epoch 29/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 19.8539 - accuracy: 0.0000e+00Epoch 00028: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 19.6252 - accuracy: 0.0000e+00 - val_loss: 12.2421 - val_accuracy: 0.0000e+00
# Epoch 30/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 19.5238 - accuracy: 0.0000e+00Epoch 00029: val_loss did not improve
# 12/12 [==============================] - 0s 17ms/step - loss: 19.3343 - accuracy: 0.0000e+00 - val_loss: 12.4519 - val_accuracy: 0.0000e+00
# Epoch 31/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 20.0005 - accuracy: 0.0000e+00Epoch 00030: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 19.7710 - accuracy: 0.0000e+00 - val_loss: 12.4011 - val_accuracy: 0.0000e+00
# Epoch 32/1000
# embeddings loaded
# Epoch 00031: val_loss did not improve
# 12/12 [==============================] - 0s 17ms/step - loss: 19.0999 - accuracy: 0.0000e+00 - val_loss: 12.1834 - val_accuracy: 0.0000e+00
# Epoch 33/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 19.1213 - accuracy: 0.0000e+00Epoch 00032: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 19.0110 - accuracy: 0.0000e+00 - val_loss: 12.4228 - val_accuracy: 0.0000e+00
# Epoch 34/1000
# embeddings loaded
# Epoch 00033: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 19.1396 - accuracy: 0.0000e+00 - val_loss: 12.4485 - val_accuracy: 0.0000e+00
# Epoch 35/1000
# embeddings loaded
# Epoch 00034: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 19.0914 - accuracy: 0.0000e+00 - val_loss: 12.1984 - val_accuracy: 0.0000e+00
# Epoch 36/1000
# embeddings loaded
# Epoch 00035: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 18.8355 - accuracy: 0.0000e+00 - val_loss: 12.3307 - val_accuracy: 0.0000e+00
# Epoch 37/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 19.0836 - accuracy: 0.0000e+00Epoch 00036: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 18.8268 - accuracy: 0.0000e+00 - val_loss: 12.3780 - val_accuracy: 0.0000e+00
# Epoch 38/1000
# embeddings loaded
# Epoch 00037: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 19.5369 - accuracy: 0.0000e+00 - val_loss: 12.1921 - val_accuracy: 0.0000e+00
# Epoch 39/1000
# embeddings loaded
# Epoch 00038: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 19.4929 - accuracy: 0.0000e+00 - val_loss: 12.4107 - val_accuracy: 0.0000e+00
# Epoch 40/1000
#  1/12 [=>............................] - ETA: 0s - loss: 17.2541 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 19.2777 - accuracy: 0.0000e+00Epoch 00039: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 19.1673 - accuracy: 0.0000e+00 - val_loss: 12.3334 - val_accuracy: 0.0000e+00
# Epoch 41/1000
# embeddings loaded
# Epoch 00040: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 18.4674 - accuracy: 0.0000e+00 - val_loss: 12.1181 - val_accuracy: 0.0000e+00
# Epoch 42/1000
# embeddings loaded
# Epoch 00041: val_loss did not improve
# 12/12 [==============================] - 0s 29ms/step - loss: 19.2207 - accuracy: 0.0000e+00 - val_loss: 12.3330 - val_accuracy: 0.0000e+00
# Epoch 43/1000
# embeddings loaded
# Epoch 00042: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 19.1468 - accuracy: 0.0000e+00 - val_loss: 12.4095 - val_accuracy: 0.0000e+00
# Epoch 44/1000
# embeddings loaded
# Epoch 00043: val_loss did not improve
# 12/12 [==============================] - 0s 29ms/step - loss: 18.6770 - accuracy: 0.0000e+00 - val_loss: 12.1241 - val_accuracy: 0.0000e+00
# Epoch 45/1000
# embeddings loaded
# Epoch 00044: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 19.2898 - accuracy: 0.0000e+00 - val_loss: 12.3937 - val_accuracy: 0.0000e+00
# Epoch 46/1000
# embeddings loaded
# Epoch 00045: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.6317 - accuracy: 0.0000e+00 - val_loss: 12.3498 - val_accuracy: 0.0000e+00
# Epoch 47/1000
# embeddings loaded
# Epoch 00046: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 19.2903 - accuracy: 0.0000e+00 - val_loss: 12.2977 - val_accuracy: 0.0000e+00
# Epoch 48/1000
# embeddings loaded
#  - ETA: 0s - loss: 19.9884 - accuracy: 0.0000e+00Epoch 00047: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 19.7144 - accuracy: 0.0000e+00 - val_loss: 12.2918 - val_accuracy: 0.0000e+00
# Epoch 49/1000
# embeddings loaded
# Epoch 00048: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 18.4978 - accuracy: 0.0000e+00 - val_loss: 12.4573 - val_accuracy: 0.0000e+00
# Epoch 50/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.6609 - accuracy: 0.0000e+00Epoch 00049: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 18.4227 - accuracy: 0.0000e+00 - val_loss: 12.2909 - val_accuracy: 0.0000e+00
# Epoch 51/1000
# embeddings loaded
# Epoch 00050: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 18.7216 - accuracy: 0.0000e+00 - val_loss: 12.1189 - val_accuracy: 0.0000e+00
# Epoch 52/1000
# embeddings loaded
# Epoch 00051: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 18.6855 - accuracy: 0.0000e+00 - val_loss: 12.4246 - val_accuracy: 0.0000e+00
# Epoch 53/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.6207 - accuracy: 0.0000e+00Epoch 00052: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 18.3588 - accuracy: 0.0000e+00 - val_loss: 12.3209 - val_accuracy: 0.0000e+00
# Epoch 54/1000
# embeddings loaded
# Epoch 00053: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 18.9162 - accuracy: 0.0000e+00 - val_loss: 11.9951 - val_accuracy: 0.0000e+00
# Epoch 55/1000
# embeddings loaded
# Epoch 00054: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 18.8793 - accuracy: 0.0000e+00 - val_loss: 12.3049 - val_accuracy: 0.0000e+00
# Epoch 56/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 19.0909 - accuracy: 0.0000e+00Epoch 00055: val_loss did not improve
# 12/12 [==============================] - 0s 30ms/step - loss: 18.7407 - accuracy: 0.0000e+00 - val_loss: 12.2966 - val_accuracy: 0.0000e+00
# Epoch 57/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.7028 - accuracy: 0.0000e+00Epoch 00056: val_loss did not improve
# 12/12 [==============================] - 0s 30ms/step - loss: 18.3146 - accuracy: 0.0000e+00 - val_loss: 12.2444 - val_accuracy: 0.0000e+00
# Epoch 58/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.5265 - accuracy: 0.0000e+00Epoch 00057: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 18.2628 - accuracy: 0.0000e+00 - val_loss: 12.2886 - val_accuracy: 0.0000e+00
# Epoch 59/1000
# embeddings loaded
# Epoch 00058: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 19.1401 - accuracy: 0.0000e+00 - val_loss: 12.3015 - val_accuracy: 0.0000e+00
# Epoch 60/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.7375 - accuracy: 0.0000e+00Epoch 00059: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.4987 - accuracy: 0.0000e+00 - val_loss: 12.1112 - val_accuracy: 0.0000e+00
# Epoch 61/1000
#  1/12 [=>............................] - ETA: 0s - loss: 19.3168 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 18.7614 - accuracy: 0.0000e+00Epoch 00060: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.2193 - accuracy: 0.0000e+00 - val_loss: 12.3245 - val_accuracy: 0.0000e+00
# Epoch 62/1000
# embeddings loaded
# Epoch 00061: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.5329 - accuracy: 0.0000e+00 - val_loss: 12.1655 - val_accuracy: 0.0000e+00
# Epoch 63/1000
# embeddings loaded
# Epoch 00062: val_loss did not improve
# 12/12 [==============================] - 0s 31ms/step - loss: 18.2917 - accuracy: 0.0000e+00 - val_loss: 12.0145 - val_accuracy: 0.0000e+00
# Epoch 64/1000
# embeddings loaded
# Epoch 00063: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 18.2412 - accuracy: 0.0000e+00 - val_loss: 12.1630 - val_accuracy: 0.0000e+00
# Epoch 65/1000
# embeddings loaded
# Epoch 00064: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.7855 - accuracy: 0.0000e+00 - val_loss: 12.2693 - val_accuracy: 0.0000e+00
# Epoch 66/1000
# embeddings loaded
# Epoch 00065: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.7024 - accuracy: 0.0000e+00 - val_loss: 11.8252 - val_accuracy: 0.0000e+00
# Epoch 67/1000
# embeddings loaded
#  9/12 [=====================>........] - ETA: 0s - loss: 19.0305 - accuracy: 0.0000e+00Epoch 00066: val_loss did not improve
# 12/12 [==============================] - 0s 28ms/step - loss: 18.4921 - accuracy: 0.0000e+00 - val_loss: 12.2401 - val_accuracy: 0.0000e+00
# Epoch 68/1000
# 11/12 [==========================>...]embeddings loaded - ETA: 0s - loss: 18.4802 - accuracy: 0.0000e+00
# Epoch 00067: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 18.3317 - accuracy: 0.0000e+00 - val_loss: 12.1641 - val_accuracy: 0.0000e+00
# Epoch 69/1000
# embeddings loaded
# Epoch 00068: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 18.6923 - accuracy: 0.0000e+00 - val_loss: 11.8744 - val_accuracy: 0.0000e+00
# Epoch 70/1000
#  4/12 [=========>....................] - ETA: 0s - loss: 17.3438 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00069: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 18.5891 - accuracy: 0.0000e+00 - val_loss: 12.0600 - val_accuracy: 0.0000e+00
# Epoch 71/1000
# embeddings loaded
# Epoch 00070: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 18.1376 - accuracy: 0.0000e+00 - val_loss: 12.0284 - val_accuracy: 0.0000e+00
# Epoch 72/1000
# embeddings loaded
# Epoch 00071: val_loss did not improve
# 12/12 [==============================] - 0s 29ms/step - loss: 18.4157 - accuracy: 0.0000e+00 - val_loss: 11.8648 - val_accuracy: 0.0000e+00
# Epoch 73/1000
# embeddings loaded
# Epoch 00072: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.5864 - accuracy: 0.0000e+00 - val_loss: 11.9602 - val_accuracy: 0.0000e+00
# Epoch 74/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.8439 - accuracy: 0.0000e+00Epoch 00073: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.5932 - accuracy: 0.0000e+00 - val_loss: 12.1322 - val_accuracy: 0.0000e+00
# Epoch 75/1000
# embeddings loaded
# Epoch 00074: val_loss did not improve
# 12/12 [==============================] - 0s 29ms/step - loss: 18.5167 - accuracy: 0.0000e+00 - val_loss: 11.5026 - val_accuracy: 0.0000e+00
# Epoch 76/1000
# embeddings loaded
# Epoch 00075: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.5291 - accuracy: 0.0000e+00 - val_loss: 11.6945 - val_accuracy: 0.0000e+00
# Epoch 77/1000
# embeddings loaded
# Epoch 00076: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 17.7741 - accuracy: 0.0000e+00 - val_loss: 11.5887 - val_accuracy: 0.0000e+00
# Epoch 78/1000
# embeddings loaded
# Epoch 00077: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 17.8382 - accuracy: 0.0000e+00 - val_loss: 11.2897 - val_accuracy: 0.0000e+00
# Epoch 79/1000
# embeddings loaded
# Epoch 00078: val_loss did not improve
# 12/12 [==============================] - 0s 28ms/step - loss: 17.9985 - accuracy: 0.0000e+00 - val_loss: 11.4277 - val_accuracy: 0.0000e+00
# Epoch 80/1000
# embeddings loaded
# Epoch 00079: val_loss did not improve
# 12/12 [==============================] - 0s 32ms/step - loss: 17.6296 - accuracy: 0.0000e+00 - val_loss: 11.7241 - val_accuracy: 0.0000e+00
# Epoch 81/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.1655 - accuracy: 0.0000e+00Epoch 00080: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 17.9606 - accuracy: 0.0000e+00 - val_loss: 10.3737 - val_accuracy: 0.0091
# Epoch 82/1000
# embeddings loaded
# Epoch 00081: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 17.6994 - accuracy: 0.0000e+00 - val_loss: 11.2814 - val_accuracy: 0.0021
# Epoch 83/1000
# embeddings loaded
# Epoch 00082: val_loss did not improve
#  - 0s 22ms/step - loss: 17.9064 - accuracy: 8.2951e-04 - val_loss: 10.5363 - val_accuracy: 0.0147
# Epoch 84/1000
# embeddings loaded
# Epoch 00083: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 17.7997 - accuracy: 0.0059 - val_loss: 10.2087 - val_accuracy: 0.0231
# Epoch 85/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 17.3692 - accuracy: 0.0191Epoch 00084: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 16.9445 - accuracy: 0.0244 - val_loss: 10.0224 - val_accuracy: 0.0467
# Epoch 86/1000
# embeddings loaded
# Epoch 00085: val_loss improved from 9.95465 to 9.43267, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 40ms/step - loss: 16.5952 - accuracy: 0.0264 - val_loss: 9.4327 - val_accuracy: 0.0832
# Epoch 87/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.5552 - accuracy: 0.0404embeddings loaded
# Epoch 00086: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 16.4384 - accuracy: 0.0570 - val_loss: 9.5520 - val_accuracy: 0.0897
# Epoch 88/1000
# embeddings loaded
# Epoch 00087: val_loss improved from 9.43267 to 9.14818, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 31ms/step - loss: 22.4151 - accuracy: 0.0000e+00 - val_loss: 9.1482 - val_accuracy: 0.1109
# Epoch 89/1000
#  1/12 [=>............................] - ETA: 0s - loss: 19.4805 - accuracy: 0.0000e+00embeddings loaded
#  8/12 [===================>..........] - ETA: 0s - loss: 20.9930 - accuracy: 0.0000e+00Epoch 00088: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 20.8618 - accuracy: 0.0000e+00 - val_loss: 10.0182 - val_accuracy: 0.0409
# Epoch 90/1000
# embeddings loaded
# Epoch 00089: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 20.6846 - accuracy: 0.0000e+00 - val_loss: 10.2421 - val_accuracy: 0.0294
# Epoch 91/1000
# embeddings loaded
# Epoch 00090: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 19.9192 - accuracy: 0.0000e+00 - val_loss: 11.1705 - val_accuracy: 0.0031
# Epoch 92/1000
# embeddings loaded
# Epoch 00091: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 19.2063 - accuracy: 0.0000e+00 - val_loss: 11.1989 - val_accuracy: 0.0047
# Epoch 93/1000
# embeddings loaded
# Epoch 00092: val_loss did not improve
# 12/12 [==============================] - 0s 17ms/step - loss: 19.5503 - accuracy: 0.0000e+00 - val_loss: 10.7745 - val_accuracy: 0.0000e+00
# Epoch 94/1000
# embeddings loaded
# Epoch 00093: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 19.0984 - accuracy: 0.0000e+00 - val_loss: 11.3591 - val_accuracy: 5.3050e-04
# Epoch 95/1000
# embeddings loaded
# Epoch 00094: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.1883 - accuracy: 0.0000e+00 - val_loss: 11.5332 - val_accuracy: 0.0000e+00
# Epoch 96/1000
# embeddings loaded
# Epoch 00095: val_loss did not improve
#  - 0s 22ms/step - loss: 19.1160 - accuracy: 0.0000e+00 - val_loss: 11.6167 - val_accuracy: 0.0000e+00
# Epoch 97/1000
# embeddings loaded
# Epoch 00096: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.8714 - accuracy: 0.0000e+00 - val_loss: 11.3674 - val_accuracy: 0.0000e+00
# Epoch 98/1000
# embeddings loaded
# Epoch 00097: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.5871 - accuracy: 0.0000e+00 - val_loss: 11.8850 - val_accuracy: 0.0000e+00
# Epoch 99/1000
#  1/12 [=>............................] - ETA: 0s - loss: 21.3534 - accuracy: 0.0000e+00embeddings loaded
#  6/12 [==============>...............] - ETA: 0s - loss: 19.4532 - accuracy: 0.0000e+00Epoch 00098: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 18.7716 - accuracy: 0.0000e+00 - val_loss: 11.6721 - val_accuracy: 0.0000e+00
# Epoch 100/1000
# embeddings loaded
# Epoch 00099: val_loss did not improve
# 12/12 [==============================] - 0s 17ms/step - loss: 18.1204 - accuracy: 0.0000e+00 - val_loss: 11.6862 - val_accuracy: 0.0000e+00
# Epoch 101/1000
# embeddings loaded
# Epoch 00100: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 18.6794 - accuracy: 0.0000e+00 - val_loss: 12.1111 - val_accuracy: 0.0000e+00
# Epoch 102/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.7393 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 18.9917 - accuracy: 0.0000e+00Epoch 00101: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 18.9011 - accuracy: 0.0000e+00 - val_loss: 11.4585 - val_accuracy: 0.0000e+00
# Epoch 103/1000
#  1/12 [=>............................] - ETA: 0s - loss: 20.4752 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00102: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 17.9505 - accuracy: 0.0000e+00 - val_loss: 11.4507 - val_accuracy: 0.0000e+00
# Epoch 104/1000
#  6/12 [==============>...............] - ETA: 0s - loss: 19.0426 - accuracy: 0.0000e+00embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.7251 - accuracy: 0.0000e+00Epoch 00103: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 18.6012 - accuracy: 0.0000e+00 - val_loss: 11.6555 - val_accuracy: 0.0000e+00
# Epoch 105/1000
# embeddings loaded
# Epoch 00104: val_loss did not improve
# 12/12 [==============================] - 0s 16ms/step - loss: 19.1568 - accuracy: 0.0000e+00 - val_loss: 11.9728 - val_accuracy: 0.0000e+00
# Epoch 106/1000
# embeddings loaded
# Epoch 00105: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 18.0757 - accuracy: 0.0000e+00 - val_loss: 11.7398 - val_accuracy: 0.0000e+00
# Epoch 107/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 18.6613 - accuracy: 0.0000e+00Epoch 00106: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 18.4398 - accuracy: 0.0000e+00 - val_loss: 11.8039 - val_accuracy: 0.0000e+00
# Epoch 108/1000
# embeddings loaded
# Epoch 00107: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 17.6290 - accuracy: 0.0000e+00 - val_loss: 11.9911 - val_accuracy: 0.0000e+00
# Epoch 109/1000
# embeddings loaded....................] - ETA: 0s - loss: 17.5203 - accuracy: 0.0000e+00
# Epoch 00108: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 17.9307 - accuracy: 0.0000e+00 - val_loss: 11.7032 - val_accuracy: 0.0000e+00
# Epoch 110/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.7795 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 18.8197 - accuracy: 0.0000e+00Epoch 00109: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 18.4771 - accuracy: 0.0000e+00 - val_loss: 11.6707 - val_accuracy: 0.0000e+00
# Epoch 111/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.9324 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00110: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 18.7019 - accuracy: 0.0000e+00 - val_loss: 11.7007 - val_accuracy: 0.0010
# Epoch 112/1000
# embeddings loaded
# 10/12 [========================>.....] - ETA: 0s - loss: 18.3033 - accuracy: 0.0000e+00Epoch 00111: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.2486 - accuracy: 0.0000e+00 - val_loss: 11.8100 - val_accuracy: 0.0000e+00
# Epoch 113/1000
# embeddings loaded
# Epoch 00112: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 18.6674 - accuracy: 0.0000e+00 - val_loss: 11.5019 - val_accuracy: 0.0000e+00
# Epoch 114/1000
# embeddings loaded
# Epoch 00113: val_loss did not improve
# 12/12 [==============================] - 0s 28ms/step - loss: 18.8900 - accuracy: 0.0000e+00 - val_loss: 11.6116 - val_accuracy: 0.0016
# Epoch 115/1000
# embeddings loaded
# Epoch 00114: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 18.5945 - accuracy: 0.0000e+00 - val_loss: 11.4788 - val_accuracy: 5.2383e-04
# Epoch 116/1000
# embeddings loaded
# Epoch 00115: val_loss did not improve
# 12/12 [==============================] - 0s 26ms/step - loss: 17.9184 - accuracy: 0.0000e+00 - val_loss: 11.6564 - val_accuracy: 0.0000e+00
# Epoch 117/1000
# embeddings loaded
# Epoch 00116: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 18.8822 - accuracy: 0.0000e+00 - val_loss: 11.5291 - val_accuracy: 0.0000e+00
# Epoch 118/1000
# embeddings loaded
# Epoch 00117: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 18.3644 - accuracy: 0.0000e+00 - val_loss: 11.4152 - val_accuracy: 0.0016
# Epoch 119/1000
# embeddings loaded
# Epoch 00118: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 18.4299 - accuracy: 0.0000e+00 - val_loss: 10.7516 - val_accuracy: 0.0054
# Epoch 120/1000
# embeddings loaded
# Epoch 00119: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 18.3431 - accuracy: 0.0000e+00 - val_loss: 11.3596 - val_accuracy: 0.0010
# Epoch 121/1000
# embeddings loaded
# Epoch 00120: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 18.3805 - accuracy: 0.0019 - val_loss: 11.4147 - val_accuracy: 0.0026
# Epoch 122/1000
#  1/12 [=>............................] - ETA: 0s - loss: 15.6515 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00121: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 17.3488 - accuracy: 9.7817e-04 - val_loss: 10.7664 - val_accuracy: 0.0198
# Epoch 123/1000
#  1/12 [=>............................] - ETA: 0s - loss: 19.3817 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00122: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 17.9616 - accuracy: 0.0029 - val_loss: 11.1468 - val_accuracy: 0.0084
# Epoch 124/1000
# embeddings loaded
# Epoch 00123: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 17.6710 - accuracy: 0.0038 - val_loss: 11.6871 - val_accuracy: 0.0047
# Epoch 125/1000
# embeddings loaded
# Epoch 00124: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 17.2002 - accuracy: 0.0045 - val_loss: 11.0329 - val_accuracy: 0.0175
# Epoch 126/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 17.3668 - accuracy: 0.0148Epoch 00125: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 17.3049 - accuracy: 0.0136 - val_loss: 10.1033 - val_accuracy: 0.0489
# Epoch 127/1000
# embeddings loaded
# Epoch 00126: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 17.0027 - accuracy: 0.0291 - val_loss: 10.3172 - val_accuracy: 0.0567
# Epoch 128/1000
# embeddings loaded
# Epoch 00127: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 16.0683 - accuracy: 0.0674 - val_loss: 9.3155 - val_accuracy: 0.1028
# Epoch 129/1000
# embeddings loaded
# Epoch 00128: val_loss improved from 9.14818 to 9.07166, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 31ms/step - loss: 17.6406 - accuracy: 0.0684 - val_loss: 9.0717 - val_accuracy: 0.1163
# Epoch 130/1000
#  1/12 [=>............................] - ETA: 0s - loss: 14.5871 - accuracy: 0.2100embeddings loaded
# Epoch 00129: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 15.8609 - accuracy: 0.0753 - val_loss: 9.4596 - val_accuracy: 0.1245
# Epoch 131/1000
# embeddings loaded
# Epoch 00130: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 24.3061 - accuracy: 0.0000e+00 - val_loss: 9.8744 - val_accuracy: 0.0494
# Epoch 132/1000
# embeddings loaded
# 10/12 [========================>.....] - ETA: 0s - loss: 20.6779 - accuracy: 0.0000e+00Epoch 00131: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 20.1909 - accuracy: 0.0000e+00 - val_loss: 10.0260 - val_accuracy: 0.0103
# Epoch 133/1000
#  1/12 [=>............................] - ETA: 0s - loss: 21.1677 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00132: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 19.9036 - accuracy: 0.0000e+00 - val_loss: 10.4867 - val_accuracy: 0.0037
# Epoch 134/1000
# embeddings loaded
# Epoch 00133: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.4830 - accuracy: 0.0000e+00 - val_loss: 10.6869 - val_accuracy: 0.0058
# Epoch 135/1000
# embeddings loaded
# Epoch 00134: val_loss did not improve
# 12/12 [==============================] - 0s 16ms/step - loss: 17.7089 - accuracy: 8.3942e-04 - val_loss: 10.1983 - val_accuracy: 0.0150
# Epoch 136/1000
# embeddings loaded
# Epoch 00135: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 17.2282 - accuracy: 0.0021 - val_loss: 10.7422 - val_accuracy: 0.0126
# Epoch 137/1000
# embeddings loaded
# Epoch 00136: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 16.6564 - accuracy: 0.0097 - val_loss: 9.2581 - val_accuracy: 0.0723
# Epoch 138/1000
# embeddings loaded
# Epoch 00137: val_loss improved from 9.07166 to 7.75309, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 30ms/step - loss: 15.2304 - accuracy: 0.0516 - val_loss: 7.7531 - val_accuracy: 0.1454
# Epoch 139/1000
#  1/12 [=>............................] - ETA: 0s - loss: 15.1872 - accuracy: 0.1010embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 14.8151 - accuracy: 0.0857Epoch 00138: val_loss improved from 7.75309 to 6.52993, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 24ms/step - loss: 14.5222 - accuracy: 0.1095 - val_loss: 6.5299 - val_accuracy: 0.3237
# Epoch 140/1000
#  1/12 [=>............................] - ETA: 0s - loss: 21.8044 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 23.5027 - accuracy: 0.0000e+00Epoch 00139: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 22.5083 - accuracy: 0.0000e+00 - val_loss: 8.0084 - val_accuracy: 0.1808
# Epoch 141/1000
# embeddings loaded
# Epoch 00140: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 20.5627 - accuracy: 0.0000e+00 - val_loss: 8.6720 - val_accuracy: 0.0781
# Epoch 142/1000
#  1/12 [=>............................] - ETA: 0s - loss: 22.5811 - accuracy: 0.0000e+00embeddings loaded
#  6/12 [==============>...............] - ETA: 0s - loss: 20.2587 - accuracy: 0.0000e+00Epoch 00141: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 19.9288 - accuracy: 0.0000e+00 - val_loss: 9.5733 - val_accuracy: 0.0427
# Epoch 143/1000
#  1/12 [=>............................] - ETA: 0s - loss: 17.4148 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00142: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 18.4365 - accuracy: 0.0000e+00 - val_loss: 9.9571 - val_accuracy: 0.0268
# Epoch 144/1000
#  1/12 [=>............................] - ETA: 0s - loss: 20.4655 - accuracy: 0.0000e+00embeddings loaded
#  6/12 [==============>...............] - ETA: 0s - loss: 19.6156 - accuracy: 0.0000e+00Epoch 00143: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.5489 - accuracy: 0.0000e+00 - val_loss: 9.8353 - val_accuracy: 0.0237
# Epoch 145/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.2408 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00144: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.0095 - accuracy: 0.0000e+00 - val_loss: 9.4200 - val_accuracy: 0.0348
# Epoch 146/1000
# embeddings loaded
# Epoch 00145: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 17.6554 - accuracy: 0.0019 - val_loss: 10.1276 - val_accuracy: 0.0426
# Epoch 147/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.9755 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00146: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 17.8667 - accuracy: 0.0064 - val_loss: 9.8526 - val_accuracy: 0.0570
# Epoch 148/1000
#  1/12 [=>............................] - ETA: 0s - loss: 12.0215 - accuracy: 0.0303embeddings loaded
#  5/12 [===========>..................] - ETA: 0s - loss: 16.3395 - accuracy: 0.0161Epoch 00147: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 16.4199 - accuracy: 0.0167 - val_loss: 9.0722 - val_accuracy: 0.0834
# Epoch 149/1000
#  1/12 [=>............................] - ETA: 0s - loss: 17.7041 - accuracy: 0.0385embeddings loaded
# Epoch 00148: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 16.6024 - accuracy: 0.0423 - val_loss: 8.0014 - val_accuracy: 0.1549
# Epoch 150/1000
# embeddings loaded
# Epoch 00149: val_loss did not improve
# 12/12 [==============================] - 0s 16ms/step - loss: 15.5131 - accuracy: 0.0918 - val_loss: 8.3203 - val_accuracy: 0.1997
# Epoch 151/1000
# embeddings loaded
# Epoch 00150: val_loss improved from 6.52993 to 6.03697, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 28ms/step - loss: 14.9637 - accuracy: 0.1394 - val_loss: 6.0370 - val_accuracy: 0.3484
# Epoch 152/1000
#  1/12 [=>............................] - ETA: 0s - loss: 12.8580 - accuracy: 0.2785embeddings loaded
#  8/12 [===================>..........] - ETA: 0s - loss: 14.8407 - accuracy: 0.1834Epoch 00151: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 14.5961 - accuracy: 0.1814 - val_loss: 8.0667 - val_accuracy: 0.3610
# Epoch 153/1000
#  1/12 [=>............................] - ETA: 0s - loss: 30.7694 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00152: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 24.0101 - accuracy: 9.6490e-04 - val_loss: 7.8463 - val_accuracy: 0.1538
# Epoch 154/1000
#  1/12 [=>............................] - ETA: 0s - loss: 24.2961 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00153: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 18.6779 - accuracy: 0.0018 - val_loss: 7.2693 - val_accuracy: 0.1524
# Epoch 155/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.5811 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00154: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 17.8459 - accuracy: 0.0000e+00 - val_loss: 8.3277 - val_accuracy: 0.0929
# Epoch 156/1000
#  1/12 [=>............................] - ETA: 0s - loss: 17.1469 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 16.5931 - accuracy: 0.0000e+00Epoch 00155: val_loss did not improve
# 12/12 [==============================] - 0s 16ms/step - loss: 16.7645 - accuracy: 0.0016 - val_loss: 7.1144 - val_accuracy: 0.1812
# Epoch 157/1000
# embeddings loaded
# Epoch 00156: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 14.5544 - accuracy: 0.0727 - val_loss: 7.0293 - val_accuracy: 0.2332
# Epoch 158/1000
# embeddings loaded11/12 [==========================>...]: 13.3420 - accuracy: 0.1147
#  - ETA: 0s - loss: 13.3003 - accuracy: 0.1575Epoch 00157: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 13.2102 - accuracy: 0.1659 - val_loss: 7.6284 - val_accuracy: 0.4088
# Epoch 159/1000
# embeddings loaded
# Epoch 00158: val_loss improved from 6.03697 to 5.68788, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 31ms/step - loss: 13.6216 - accuracy: 0.2521 - val_loss: 5.6879 - val_accuracy: 0.5564
# Epoch 160/1000
#  1/12 [=>............................] - ETA: 0s - loss: 11.4197 - accuracy: 0.2941embeddings loaded
# Epoch 00159: val_loss improved from 5.68788 to 4.57942, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 25ms/step - loss: 13.7900 - accuracy: 0.2771 - val_loss: 4.5794 - val_accuracy: 0.5472
# Epoch 161/1000
#  1/12 [=>............................] - ETA: 0s - loss: 23.0337 - accuracy: 0.0114embeddings loaded
# Epoch 00160: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 21.8596 - accuracy: 0.0171 - val_loss: 4.7586 - val_accuracy: 0.4119
# Epoch 162/1000
#  1/12 [=>............................] - ETA: 0s - loss: 23.3947 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00161: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 19.2211 - accuracy: 0.0073 - val_loss: 5.9629 - val_accuracy: 0.2445
# Epoch 163/1000
#  1/12 [=>............................] - ETA: 0s - loss: 16.9147 - accuracy: 0.0000e+00embeddings loaded
# Epoch 00162: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 18.0627 - accuracy: 0.0055 - val_loss: 6.0346 - val_accuracy: 0.2817
# Epoch 164/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.8902 - accuracy: 0.0000e+00embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 18.2033 - accuracy: 0.0102    Epoch 00163: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 17.1569 - accuracy: 0.0130 - val_loss: 6.7071 - val_accuracy: 0.2317
# Epoch 165/1000
#  1/12 [=>............................] - ETA: 0s - loss: 18.2623 - accuracy: 0.0306embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 16.1899 - accuracy: 0.0472Epoch 00164: val_loss did not improve
# 12/12 [==============================] - 0s 15ms/step - loss: 16.2064 - accuracy: 0.0544 - val_loss: 6.5386 - val_accuracy: 0.3337
# Epoch 166/1000
# embeddings loaded
# Epoch 00165: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 14.6554 - accuracy: 0.1465 - val_loss: 5.6916 - val_accuracy: 0.4449
# Epoch 167/1000
# embeddings loaded
# Epoch 00166: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 15.0747 - accuracy: 0.2135 - val_loss: 5.2868 - val_accuracy: 0.5489
# Epoch 168/1000
# 10/12 [========================>.....]embeddings loaded: 15.0303 - accuracy: 0.2083
#  - ETA: 0s - loss: 14.9596 - accuracy: 0.2168Epoch 00167: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 14.5520 - accuracy: 0.2140 - val_loss: 4.9308 - val_accuracy: 0.5219
# Epoch 169/1000
# embeddings loaded
# Epoch 00168: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 13.3371 - accuracy: 0.2563 - val_loss: 5.1642 - val_accuracy: 0.5423
# Epoch 170/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 13.8259 - accuracy: 0.2785Epoch 00169: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 13.4573 - accuracy: 0.2838 - val_loss: 5.8984 - val_accuracy: 0.5190
# Epoch 171/1000
# embeddings loaded
# Epoch 00170: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 12.3947 - accuracy: 0.3247 - val_loss: 5.3541 - val_accuracy: 0.6229
# Epoch 172/1000
# embeddings loaded
# Epoch 00171: val_loss improved from 4.57942 to 3.92384, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 30ms/step - loss: 12.7290 - accuracy: 0.3786 - val_loss: 3.9238 - val_accuracy: 0.7100
# Epoch 173/1000
#  1/12 [=>............................] - ETA: 0s - loss: 17.5719 - accuracy: 0.2737embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 13.5819 - accuracy: 0.3050Epoch 00172: val_loss did not improve
# 12/12 [==============================] - 0s 18ms/step - loss: 12.2417 - accuracy: 0.3368 - val_loss: 4.1658 - val_accuracy: 0.6330
# Epoch 174/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 21.3228 - accuracy: 0.0569Epoch 00173: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 20.5671 - accuracy: 0.0535 - val_loss: 5.9694 - val_accuracy: 0.4310
# Epoch 175/1000
# embeddings loaded
# Epoch 00174: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 17.1149 - accuracy: 0.0359 - val_loss: 6.2254 - val_accuracy: 0.3520
# Epoch 176/1000
# embeddings loaded
#  8/12 [===================>..........] - ETA: 0s - loss: 16.4105 - accuracy: 0.0358Epoch 00175: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 15.8466 - accuracy: 0.0520 - val_loss: 4.3376 - val_accuracy: 0.4741
# Epoch 177/1000
#  4/12 [=========>....................] - ETA: 0s - loss: 13.1646 - accuracy: 0.1910embeddings loaded
#  9/12 [=====================>........] - ETA: 0s - loss: 12.9817 - accuracy: 0.1840Epoch 00176: val_loss improved from 3.92384 to 3.85422, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 26ms/step - loss: 12.7148 - accuracy: 0.1888 - val_loss: 3.8542 - val_accuracy: 0.6619
# Epoch 178/1000
#  1/12 [=>............................] - ETA: 0s - loss: 12.2728 - accuracy: 0.3021embeddings loaded
# Epoch 00177: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 11.7555 - accuracy: 0.3355 - val_loss: 4.5516 - val_accuracy: 0.7044
# Epoch 179/1000
# embeddings loaded
# Epoch 00178: val_loss improved from 3.85422 to 3.54214, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# 12/12 [==============================] - 0s 28ms/step - loss: 18.7973 - accuracy: 0.1261 - val_loss: 3.5421 - val_accuracy: 0.6121
# Epoch 180/1000
#  1/12 [=>............................] - ETA: 0s - loss: 15.0651 - accuracy: 0.1000embeddings loaded
# Epoch 00179: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 15.7886 - accuracy: 0.1171 - val_loss: 3.8884 - val_accuracy: 0.5920
# Epoch 181/1000
#  1/12 [=>............................] - ETA: 0s - loss: 17.1655 - accuracy: 0.0208embeddings loaded
# Epoch 00180: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 16.6451 - accuracy: 0.0627 - val_loss: 4.7014 - val_accuracy: 0.5941
# Epoch 182/1000
#  1/12 [=>............................] - ETA: 0s - loss: 16.2396 - accuracy: 0.0417embeddings loaded
# Epoch 00181: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 15.4706 - accuracy: 0.1161 - val_loss: 3.7869 - val_accuracy: 0.6751
# Epoch 183/1000
#  1/12 [=>............................] - ETA: 0s - loss: 11.3382 - accuracy: 0.3294embeddings loaded
# Epoch 00182: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 14.1482 - accuracy: 0.2223 - val_loss: 4.2660 - val_accuracy: 0.6742
# Epoch 184/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 13.6342 - accuracy: 0.3169Epoch 00183: val_loss improved from 3.54214 to 2.95958, saving model to ../model/weights_triplet_loss.hdf5
# Embeddings updated
# ...
# Epoch 939/1000
# embeddings loaded
# Epoch 00938: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 0.4017 - accuracy: 0.9914 - val_loss: 4.7542 - val_accuracy: 0.7811
# Epoch 940/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.4228 - accuracy: 0.9294embeddings loaded
# Epoch 00939: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4253 - accuracy: 0.9850 - val_loss: 2.5094 - val_accuracy: 0.8765
# Epoch 941/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3773 - accuracy: 1.0000embeddings loaded
# Epoch 00940: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4698 - accuracy: 0.9838 - val_loss: 5.9334 - val_accuracy: 0.7731
# Epoch 942/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.4796 - accuracy: 0.9770embeddings loaded
# Epoch 00941: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4351 - accuracy: 0.9925 - val_loss: 2.4248 - val_accuracy: 0.8736
# Epoch 943/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3772 - accuracy: 1.0000embeddings loaded
# Epoch 00942: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4103 - accuracy: 0.9924 - val_loss: 3.1622 - val_accuracy: 0.8527
# Epoch 944/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.4560 - accuracy: 0.9796embeddings loaded
#  7/12 [================>.............] - ETA: 0s - loss: 0.3991 - accuracy: 0.9955Epoch 00943: val_loss did not improve
# 12/12 [==============================] - 0s 16ms/step - loss: 0.3989 - accuracy: 0.9956 - val_loss: 4.8439 - val_accuracy: 0.8253
# Epoch 945/1000
# 10/12 [========================>.....] - ETA: 0s - loss: 0.4412 - accuracy: 0.9883embeddings loaded
# Epoch 00944: val_loss did not improve
# 12/12 [==============================] - 0s 26ms/step - loss: 0.4306 - accuracy: 0.9902 - val_loss: 3.2844 - val_accuracy: 0.8451
# Epoch 946/1000
# embeddings loaded
# Epoch 00945: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4119 - accuracy: 0.9939 - val_loss: 4.0655 - val_accuracy: 0.8575
# Epoch 947/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.5765 - accuracy: 0.9889embeddings loaded
# Epoch 00946: val_loss did not improve
# 12/12 [==============================] - 0s 26ms/step - loss: 0.4048 - accuracy: 0.9964 - val_loss: 5.4530 - val_accuracy: 0.7791
# Epoch 948/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3767 - accuracy: 1.0000embeddings loaded
# Epoch 00947: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4236 - accuracy: 0.9908 - val_loss: 5.2501 - val_accuracy: 0.8285
# Epoch 949/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3814 - accuracy: 0.9890embeddings loaded
# Epoch 00948: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4638 - accuracy: 0.9855 - val_loss: 3.2135 - val_accuracy: 0.8213
# Epoch 950/1000
# embeddings loaded
# Epoch 00949: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 0.4333 - accuracy: 0.9897 - val_loss: 4.1391 - val_accuracy: 0.8317
# Epoch 951/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3863 - accuracy: 0.9895embeddings loaded
# Epoch 00950: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 0.4008 - accuracy: 0.9937 - val_loss: 5.9463 - val_accuracy: 0.8008
# Epoch 952/1000
# embeddings loaded
# Epoch 00951: val_loss did not improve
# 12/12 [==============================] - 0s 28ms/step - loss: 0.4135 - accuracy: 0.9931 - val_loss: 2.8848 - val_accuracy: 0.8359
# Epoch 953/1000
# embeddings loaded
#  9/12 [=====================>........] - ETA: 0s - loss: 0.4014 - accuracy: 0.9940Epoch 00952: val_loss did not improve
# 12/12 [==============================] - 0s 28ms/step - loss: 0.3951 - accuracy: 0.9955 - val_loss: 3.8824 - val_accuracy: 0.8014
# Epoch 954/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3760 - accuracy: 1.0000embeddings loaded
# Epoch 00953: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 0.4124 - accuracy: 0.9934 - val_loss: 3.8541 - val_accuracy: 0.8152
# Epoch 955/1000
# embeddings loaded
# Epoch 00954: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4096 - accuracy: 0.9889 - val_loss: 2.5028 - val_accuracy: 0.8668
# Epoch 956/1000
# embeddings loaded
# Epoch 00955: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 0.3995 - accuracy: 0.9966 - val_loss: 3.5864 - val_accuracy: 0.8395
# Epoch 957/1000
# embeddings loaded
# Epoch 00956: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 0.3988 - accuracy: 0.9944 - val_loss: 5.3305 - val_accuracy: 0.7824
# Epoch 958/1000
# embeddings loaded
# Epoch 00957: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 0.4460 - accuracy: 0.9926 - val_loss: 2.1086 - val_accuracy: 0.8804
# Epoch 959/1000
# embeddings loaded
# Epoch 00958: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 0.4134 - accuracy: 0.9884 - val_loss: 2.9863 - val_accuracy: 0.8457
# Epoch 960/1000
#  - ETA: 0s - loss: 0.4156 - accuracy: 0.9873embeddings loaded
# Epoch 00959: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4098 - accuracy: 0.9885 - val_loss: 4.4279 - val_accuracy: 0.7918
# Epoch 961/1000
# embeddings loaded
# Epoch 00960: val_loss did not improve
# 12/12 [==============================] - 0s 33ms/step - loss: 0.4247 - accuracy: 0.9911 - val_loss: 3.4743 - val_accuracy: 0.8461
# Epoch 962/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.4485 - accuracy: 0.9780embeddings loaded
# Epoch 00961: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 0.4051 - accuracy: 0.9928 - val_loss: 3.9194 - val_accuracy: 0.8550
# Epoch 963/1000
# embeddings loaded
# Epoch 00962: val_loss did not improve
# 12/12 [==============================] - 0s 31ms/step - loss: 0.4338 - accuracy: 0.9828 - val_loss: 5.6893 - val_accuracy: 0.7533
# Epoch 964/1000
# embeddings loaded
# Epoch 00963: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 0.4180 - accuracy: 0.9867 - val_loss: 3.3395 - val_accuracy: 0.8414
# Epoch 965/1000
# embeddings loaded
# Epoch 00964: val_loss did not improve
# 12/12 [==============================] - 0s 30ms/step - loss: 0.4342 - accuracy: 0.9847 - val_loss: 3.6496 - val_accuracy: 0.8332
# Epoch 966/1000
# embeddings loaded
#  8/12 [===================>..........] - ETA: 0s - loss: 0.4431 - accuracy: 0.9881Epoch 00965: val_loss did not improve
# 12/12 [==============================] - 0s 20ms/step - loss: 0.4235 - accuracy: 0.9884 - val_loss: 4.6664 - val_accuracy: 0.8335
# Epoch 967/1000
# embeddings loaded
#  8/12 [===================>..........] - ETA: 0s - loss: 0.4656 - accuracy: 0.9785Epoch 00966: val_loss did not improve
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4593 - accuracy: 0.9828 - val_loss: 2.5353 - val_accuracy: 0.8648
# Epoch 968/1000
# embeddings loaded
# 11/12 [==========================>...] - ETA: 0s - loss: 0.4092 - accuracy: 0.9932Epoch 00967: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 0.4066 - accuracy: 0.9926 - val_loss: 3.9745 - val_accuracy: 0.8150
# Epoch 969/1000
# embeddings loaded
# Epoch 00968: val_loss did not improve
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4356 - accuracy: 0.9899 - val_loss: 3.3188 - val_accuracy: 0.8422
# Epoch 970/1000
# embeddings loaded
# Epoch 00969: val_loss did not improve
# 12/12 [==============================] - 0s 29ms/step - loss: 0.4447 - accuracy: 0.9862 - val_loss: 3.1230 - val_accuracy: 0.8599
# Epoch 971/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.4633 - accuracy: 0.9902embeddings loaded
# Epoch 00970: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4042 - accuracy: 0.9946 - val_loss: 3.0134 - val_accuracy: 0.8885
# Epoch 972/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3745 - accuracy: 1.0000embeddings loaded
# Epoch 00971: val_loss did not improve
# 12/12 [==============================] - 0s 26ms/step - loss: 0.3932 - accuracy: 0.9917 - val_loss: 2.7155 - val_accuracy: 0.8774
# Epoch 973/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3744 - accuracy: 1.0000embeddings loaded
# Epoch 00972: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 0.3983 - accuracy: 0.9928 - val_loss: 2.7780 - val_accuracy: 0.8669
# Epoch 974/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.6048 - accuracy: 0.9691embeddings loaded
# Epoch 00973: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4369 - accuracy: 0.9893 - val_loss: 3.6281 - val_accuracy: 0.8309
# Epoch 975/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3743 - accuracy: 1.0000embeddings loaded
# Epoch 00974: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.3997 - accuracy: 0.9938 - val_loss: 3.0375 - val_accuracy: 0.8355
# Epoch 976/1000
# embeddings loaded
# Epoch 00975: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4041 - accuracy: 0.9917 - val_loss: 4.3025 - val_accuracy: 0.8181
# Epoch 977/1000
# embeddings loaded
#  8/12 [===================>..........] - ETA: 0s - loss: 0.4247 - accuracy: 0.9934Epoch 00976: val_loss did not improve
# 12/12 [==============================] - 0s 26ms/step - loss: 0.4652 - accuracy: 0.9888 - val_loss: 2.2976 - val_accuracy: 0.8694
# Epoch 978/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3740 - accuracy: 1.0000embeddings loaded
# Epoch 00977: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4087 - accuracy: 0.9888 - val_loss: 3.4798 - val_accuracy: 0.8164
# Epoch 979/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.5473 - accuracy: 0.9512embeddings loaded
# Epoch 00978: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 0.4458 - accuracy: 0.9841 - val_loss: 3.8418 - val_accuracy: 0.8392
# Epoch 980/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3738 - accuracy: 1.0000embeddings loaded
# Epoch 00979: val_loss did not improve
# 12/12 [==============================] - 0s 26ms/step - loss: 0.4283 - accuracy: 0.9888 - val_loss: 4.8728 - val_accuracy: 0.7957
# Epoch 981/1000
#  6/12 [==============>...............]embeddings loaded: 0.3738 - accuracy: 1.0000
# Epoch 00980: val_loss did not improve
# 12/12 [==============================] - 0s 26ms/step - loss: 0.4049 - accuracy: 0.9949 - val_loss: 2.5197 - val_accuracy: 0.8716
# Epoch 982/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3737 - accuracy: 1.0000embeddings loaded
# Epoch 00981: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4017 - accuracy: 0.9947 - val_loss: 3.0762 - val_accuracy: 0.8697
# Epoch 983/1000
# embeddings loaded
# Epoch 00982: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4313 - accuracy: 0.9901 - val_loss: 2.5830 - val_accuracy: 0.8868
# Epoch 984/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.5082 - accuracy: 0.9891embeddings loaded
# Epoch 00983: val_loss did not improve
# 12/12 [==============================] - 0s 25ms/step - loss: 0.4198 - accuracy: 0.9892 - val_loss: 2.1910 - val_accuracy: 0.8751
# Epoch 985/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3734 - accuracy: 1.0000embeddings loaded
# Epoch 00984: val_loss did not improve
# 12/12 [==============================] - 0s 27ms/step - loss: 0.3911 - accuracy: 0.9956 - val_loss: 4.3955 - val_accuracy: 0.8143
# Epoch 986/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3733 - accuracy: 1.0000embeddings loaded
# Epoch 00985: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 0.3956 - accuracy: 0.9937 - val_loss: 3.6462 - val_accuracy: 0.8252
# Epoch 987/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3732 - accuracy: 1.0000embeddings loaded
# Epoch 00986: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4083 - accuracy: 0.9947 - val_loss: 4.1857 - val_accuracy: 0.8173
# Epoch 988/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3730 - accuracy: 1.0000embeddings loaded
# Epoch 00987: val_loss did not improve
# 12/12 [==============================] - 0s 22ms/step - loss: 0.3872 - accuracy: 0.9951 - val_loss: 3.3194 - val_accuracy: 0.8370
# Epoch 989/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3729 - accuracy: 1.0000embeddings loaded
# Epoch 00988: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4227 - accuracy: 0.9928 - val_loss: 3.3363 - val_accuracy: 0.8658
# Epoch 990/1000
# embeddings loaded
# Epoch 00989: val_loss did not improve
# 12/12 [==============================] - 0s 19ms/step - loss: 0.3881 - accuracy: 0.9973 - val_loss: 3.0074 - val_accuracy: 0.8590
# Epoch 991/1000
# embeddings loaded
# Epoch 00990: val_loss did not improve
# 12/12 [==============================] - 0s 28ms/step - loss: 0.3932 - accuracy: 0.9965 - val_loss: 3.0297 - val_accuracy: 0.8623
# Epoch 992/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3725 - accuracy: 1.0000embeddings loaded
# Epoch 00991: val_loss did not improve
# 12/12 [==============================] - 0s 24ms/step - loss: 0.3843 - accuracy: 0.9937 - val_loss: 3.7233 - val_accuracy: 0.8105
# Epoch 993/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3724 - accuracy: 1.0000embeddings loaded
# Epoch 00992: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4254 - accuracy: 0.9904 - val_loss: 4.9001 - val_accuracy: 0.8054
# Epoch 994/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3723 - accuracy: 1.0000embeddings loaded
# Epoch 00993: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4269 - accuracy: 0.9896 - val_loss: 4.6786 - val_accuracy: 0.8119
# Epoch 995/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.3722 - accuracy: 1.0000embeddings loaded
# Epoch 00994: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4025 - accuracy: 0.9933 - val_loss: 2.8955 - val_accuracy: 0.8334
# Epoch 996/1000
#  1/12 [=>............................] - ETA: 0s - loss: 0.4458 - accuracy: 0.9896embeddings loaded
# Epoch 00995: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4118 - accuracy: 0.9924 - val_loss: 4.0506 - val_accuracy: 0.8226
# Epoch 997/1000
# embeddings loaded
# Epoch 00996: val_loss did not improve
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4144 - accuracy: 0.9933 - val_loss: 6.0908 - val_accuracy: 0.7724
# Epoch 998/1000
# embeddings loaded
# Epoch 00997: val_loss did not improve
# 12/12 [==============================] - 0s 28ms/step - loss: 0.3841 - accuracy: 0.9965 - val_loss: 4.8317 - val_accuracy: 0.7760
# Epoch 999/1000
# embeddings loaded
# 10/12 [========================>.....] - ETA: 0s - loss: 0.4295 - accuracy: 0.9898Epoch 00998: val_loss did not improve
#  - 0s 22ms/step - loss: 0.4199 - accuracy: 0.9906 - val_loss: 3.7607 - val_accuracy: 0.8221
# Epoch 1000/1000
# embeddings loaded
#  - ETA: 0s - loss: 0.4141 - accuracy: 0.9915Epoch 00999: val_loss did not improve
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4062 - accuracy: 0.9928 - val_loss: 4.0843 - val_accuracy: 0.8227
# INFO:__main__:Completed in 295.3607850074768 seconds
# INFO:__main__:Training result <keras.callbacks.History object at 0x127be1fd0>
# 0

# %%
clr.evaluate()
clr.train_history_visual()
# Out:
# INFO:__main__:Distance threshold 0.6626:
# INFO:__main__:Testing all authorized labels...
# INFO:__main__:data id  247 false rejected as label -1, true label 386
# INFO:__main__:data id  1768 false rejected as label 4058, true label 3738
# INFO:__main__:data id  2 false rejected as label -1, true label 128
# INFO:__main__:data id  248 false rejected as label -1, true label 386
# INFO:__main__:data id  554 false rejected as label -1, true label 1405
# INFO:__main__:data id  2082 false rejected as label -1, true label 5040
# INFO:__main__:data id  629 false rejected as label 1934, true label 1872
# INFO:__main__:data id  1816 false rejected as label -1, true label 4058
# INFO:__main__:data id  2175 false rejected as label -1, true label 5459
# INFO:__main__:data id  282 false rejected as label 3128, true label 418
# INFO:__main__:data id  1131 false rejected as label -1, true label 2469
# INFO:__main__:data id  1055 false rejected as label -1, true label 2277
# INFO:__main__:data id  669 false rejected as label 1965, true label 1872
# INFO:__main__:data id  780 false rejected as label -1, true label 1893
# INFO:__main__:data id  1030 false rejected as label -1, true label 2211
# INFO:__main__:data id  1418 false rejected as label -1, true label 2885
# INFO:__main__:data id  381 false rejected as label -1, true label 1048
# INFO:__main__:data id  425 false rejected as label -1, true label 1048
# INFO:__main__:data id  1322 false rejected as label -1, true label 2683
# INFO:__main__:data id  2133 false rejected as label -1, true label 5409
# INFO:__main__:data id  1389 false rejected as label -1, true label 2747
# INFO:__main__:data id  1573 false rejected as label -1, true label 3203
# INFO:__main__:data id  469 false rejected as label -1, true label 1208
# INFO:__main__:data id  968 false rejected as label 5429, true label 2176
# INFO:__main__:data id  472 false rejected as label -1, true label 1208
# INFO:__main__:data id  340 false rejected as label -1, true label 787
# INFO:__main__:data id  1206 false rejected as label 224, true label 2508
# INFO:__main__:data id  2014 false rejected as label -1, true label 4964
# INFO:__main__:data id  1961 false rejected as label -1, true label 4837
# INFO:__main__:data id  1432 false rejected as label -1, true label 2885
# INFO:__main__:data id  1084 false rejected as label -1, true label 2289
# INFO:__main__:data id  1893 false rejected as label 374, true label 4552
# INFO:__main__:data id  2043 false rejected as label 5355, true label 4964
# INFO:__main__:data id  383 false rejected as label 2515, true label 1048
# INFO:__main__:data id  2240 false rejected as label -1, true label 5459
# INFO:__main__:data id  1442 false rejected as label -1, true label 2885
# INFO:__main__:data id  990 false rejected as label -1, true label 2176
# INFO:__main__:data id  2147 false rejected as label -1, true label 5429
# INFO:__main__:data id  536 false rejected as label 211, true label 1405
# INFO:__main__:data id  2277 false rejected as label -1, true label 5542
# INFO:__main__:data id  859 false rejected as label 1872, true label 1965
# INFO:__main__:data id  1819 false rejected as label -1, true label 4058
# INFO:__main__:data id  1034 false rejected as label -1, true label 2211
# INFO:__main__:data id  2158 false rejected as label -1, true label 5429
# INFO:__main__:data id  943 false rejected as label -1, true label 2045
# INFO:__main__:data id  424 false rejected as label 2289, true label 1048
# INFO:__main__:data id  1241 false rejected as label -1, true label 2508
# INFO:__main__:data id  103 false rejected as label -1, true label 249
# INFO:__main__:data id  314 false rejected as label 1965, true label 532
# INFO:__main__:data id  515 false rejected as label -1, true label 1405
# INFO:__main__:data id  720 false rejected as label -1, true label 1893
# INFO:__main__:data id  1202 false rejected as label -1, true label 2507
# INFO:__main__:data id  2312 false rejected as label 374, true label 5570
# INFO:__main__:data id  488 false rejected as label -1, true label 1405
# INFO:__main__:data id  1371 false rejected as label -1, true label 2747
# INFO:__main__:data id  1593 false rejected as label 5429, true label 3328
# INFO:__main__:data id  393 false rejected as label -1, true label 1048
# INFO:__main__:data id  135 false rejected as label -1, true label 305
# INFO:__main__:data id  887 false rejected as label 5660, true label 1994
# INFO:__main__:data id  38 false rejected as label -1, true label 128
# INFO:__main__:data id  221 false rejected as label 2289, true label 374
# INFO:__main__:data id  2078 false rejected as label -1, true label 5040
# INFO:__main__:data id  595 false rejected as label -1, true label 1867
# INFO:__main__:data id  1266 false rejected as label 3203, true label 2531
# INFO:__main__:data id  1682 false rejected as label -1, true label 3402
# INFO:__main__:data id  664 false rejected as label -1, true label 1872
# INFO:__main__:data id  1352 false rejected as label -1, true label 2683
# INFO:__main__:data id  46 false rejected as label -1, true label 211
# INFO:__main__:data id  1327 false rejected as label -1, true label 2683
# INFO:__main__:data id  413 false rejected as label -1, true label 1048
# INFO:__main__:data id  273 false rejected as label -1, true label 418
# INFO:__main__:data id  799 false rejected as label -1, true label 1934
# INFO:__main__:data id  1560 false rejected as label -1, true label 3203
# INFO:__main__:data id  1337 false rejected as label -1, true label 2683
# INFO:__main__:data id  1424 false rejected as label 4552, true label 2885
# INFO:__main__:data id  1369 false rejected as label 2045, true label 2747
# INFO:__main__:data id  1431 false rejected as label 386, true label 2885
# INFO:__main__:data id  289 false rejected as label -1, true label 418
# INFO:__main__:data id  1922 false rejected as label 5409, true label 4573
# INFO:__main__:data id  1972 false rejected as label -1, true label 4837
# INFO:__main__:data id  2075 false rejected as label -1, true label 5040
# INFO:__main__:data id  1295 false rejected as label -1, true label 2571
# INFO:__main__:data id  79 false rejected as label 5570, true label 224
# INFO:__main__:data id  37 false rejected as label 2176, true label 128
# INFO:__main__:data id  1843 false rejected as label -1, true label 4243
# INFO:__main__:data id  846 false rejected as label -1, true label 1965
# INFO:__main__:data id  991 false rejected as label 374, true label 2176
# INFO:__main__:data id  2330 false rejected as label -1, true label 5570
# INFO:__main__:data id  587 false rejected as label 4573, true label 1867
# INFO:__main__:data id  1834 false rejected as label 5542, true label 4243
# INFO:__main__:data id  1075 false rejected as label -1, true label 2277
# INFO:__main__:data id  605 false rejected as label 1208, true label 1872
# INFO:__main__:data id  2066 false rejected as label 787, true label 5040
# INFO:__main__:data id  784 false rejected as label -1, true label 1893
# INFO:__main__:data id  1086 false rejected as label -1, true label 2289
# INFO:__main__:data id  1037 false rejected as label 374, true label 2211
# INFO:__main__:data id  1762 false rejected as label -1, true label 3738
# INFO:__main__:data id  1277 false rejected as label -1, true label 2531
# INFO:__main__:data id  516 false rejected as label -1, true label 1405
# INFO:__main__:data id  1879 false rejected as label 2176, true label 4552
# INFO:__main__:data id  131 false rejected as label -1, true label 305
# INFO:__main__:data id  2257 false rejected as label 5570, true label 5459
# INFO:__main__:data id  995 false rejected as label -1, true label 2176
# INFO:__main__:data id  1316 false rejected as label 787, true label 2683
# INFO:__main__:data id  967 false rejected as label -1, true label 2176
# INFO:__main__:data id  2136 false rejected as label 2469, true label 5409
# INFO:__main__:data id  307 false rejected as label -1, true label 532
# INFO:__main__:data id  1709 false rejected as label -1, true label 3435
# INFO:__main__:data id  97 false rejected as label -1, true label 249
# INFO:__main__:data id  288 false rejected as label -1, true label 418
# INFO:__main__:data id  2284 false rejected as label -1, true label 5542
# INFO:__main__:data id  2154 false rejected as label -1, true label 5429
# INFO:__main__:data id  176 false rejected as label -1, true label 374
# INFO:__main__:data id  1970 false rejected as label -1, true label 4837
# INFO:__main__:data id  2251 false rejected as label -1, true label 5459
# INFO:__main__:data id  577 false rejected as label -1, true label 1867
# INFO:__main__:data id  1964 false rejected as label -1, true label 4837
# INFO:__main__:data id  1433 false rejected as label 3738, true label 2885
# INFO:__main__:data id  373 false rejected as label -1, true label 1048
# INFO:__main__:data id  1860 false rejected as label -1, true label 4334
# INFO:__main__:data id  197 false rejected as label 2289, true label 374
# INFO:__main__:data id  1336 false rejected as label 4573, true label 2683
# INFO:__main__:data id  1474 false rejected as label -1, true label 2942
# INFO:__main__:data id  1197 false rejected as label 305, true label 2507
# INFO:__main__:data id  467 false rejected as label -1, true label 1208
# INFO:__main__:data id  1252 false rejected as label 305, true label 2515
# INFO:__main__:data id  202 false rejected as label -1, true label 374
# INFO:__main__:data id  1281 false rejected as label 2571, true label 2531
# INFO:__main__:data id  1851 false rejected as label -1, true label 4334
# INFO:__main__:data id  1323 false rejected as label -1, true label 2683
# INFO:__main__:data id  2042 false rejected as label -1, true label 4964
# INFO:__main__:data id  264 false rejected as label -1, true label 386
# INFO:__main__:data id  970 false rejected as label -1, true label 2176
# INFO:__main__:data id  369 false rejected as label -1, true label 1048
# INFO:__main__:data id  233 false rejected as label -1, true label 386
# INFO:__main__:data id  872 false rejected as label -1, true label 1994
# INFO:__main__:data id  1575 false rejected as label 4013, true label 3203
# INFO:__main__:data id  326 false rejected as label -1, true label 787
# INFO:__main__:data id  1992 false rejected as label -1, true label 4868
# INFO:__main__:data id  688 false rejected as label -1, true label 1872
# INFO:__main__:data id  700 false rejected as label 2289, true label 1893
# INFO:__main__:data id  296 false rejected as label -1, true label 532
# INFO:__main__:data id  1286 false rejected as label -1, true label 2531
# INFO:__main__:data id  832 false rejected as label -1, true label 1934
# INFO:__main__:data id  2157 false rejected as label 1872, true label 5429
# INFO:__main__:data id  1840 false rejected as label -1, true label 4243
# INFO:__main__:data id  1619 false rejected as label -1, true label 3352
# INFO:__main__:data id  24 false rejected as label -1, true label 128
# INFO:__main__:data id  1492 false rejected as label -1, true label 2942
# INFO:__main__:data id  335 false rejected as label 3128, true label 787
# INFO:__main__:data id  1201 false rejected as label 386, true label 2507
# INFO:__main__:data id  1229 false rejected as label -1, true label 2508
# INFO:__main__:data id  2126 false rejected as label -1, true label 5409
# INFO:__main__:data id  91 false rejected as label -1, true label 224
# INFO:__main__:data id  93 false rejected as label 3352, true label 224
# INFO:__main__:data id  1143 false rejected as label -1, true label 2469
# INFO:__main__:data id  2002 false rejected as label -1, true label 4868
# INFO:__main__:data id  2202 false rejected as label -1, true label 5459
# INFO:__main__:data id  1444 false rejected as label -1, true label 2942
# INFO:__main__:data id  997 false rejected as label -1, true label 2176
# INFO:__main__:data id  363 false rejected as label -1, true label 1048
# INFO:__main__:data id  655 false rejected as label -1, true label 1872
# INFO:__main__:data id  353 false rejected as label -1, true label 1048
# INFO:__main__:data id  689 false rejected as label 1208, true label 1872
# INFO:__main__:data id  2094 false rejected as label 249, true label 5355
# INFO:__main__:data id  2232 false rejected as label 1208, true label 5459
# INFO:__main__:data id  801 false rejected as label -1, true label 1934
# INFO:__main__:data id  2361 false rejected as label 1994, true label 5660
# INFO:__main__:data id  783 false rejected as label -1, true label 1893
# INFO:__main__:data id  1378 false rejected as label -1, true label 2747
# INFO:__main__:data id  660 false rejected as label -1, true label 1872
# INFO:__main__:data id  278 false rejected as label -1, true label 418
# INFO:__main__:data id  327 false rejected as label -1, true label 787
# INFO:__main__:data id  960 false rejected as label -1, true label 2176
# INFO:__main__:data id  580 false rejected as label -1, true label 1867
# INFO:__main__:data id  310 false rejected as label -1, true label 532
# INFO:__main__:data id  245 false rejected as label -1, true label 386
# INFO:__main__:data id  1165 false rejected as label -1, true label 2469
# INFO:__main__:data id  2046 false rejected as label -1, true label 4964
# INFO:__main__:data id  1543 false rejected as label -1, true label 3203
# INFO:__main__:data id  1765 false rejected as label -1, true label 3738
# INFO:__main__:data id  507 false rejected as label -1, true label 1405
# INFO:__main__:data id  1186 false rejected as label 4013, true label 2507
# INFO:__main__:data id  1396 false rejected as label -1, true label 2847
# INFO:__main__:data id  2114 false rejected as label -1, true label 5409
# INFO:__main__:data id  1130 false rejected as label -1, true label 2469
# INFO:__main__:data id  30 false rejected as label -1, true label 128
# INFO:__main__:data id  1777 false rejected as label 305, true label 4013
# INFO:__main__:data id  1076 false rejected as label -1, true label 2277
# INFO:__main__:data id  653 false rejected as label -1, true label 1872
# INFO:__main__:data id  2143 false rejected as label -1, true label 5429
# INFO:__main__:data id  1387 false rejected as label -1, true label 2747
# INFO:__main__:data id  1708 false rejected as label -1, true label 3435
# INFO:__main__:data id  320 false rejected as label 1872, true label 532
# INFO:__main__:data id  1878 false rejected as label -1, true label 4552
# INFO:__main__:data id  902 false rejected as label -1, true label 2028
# INFO:__main__:data id  2290 false rejected as label 1208, true label 5542
# INFO:__main__:data id  2148 false rejected as label -1, true label 5429
# INFO:__main__:data id  1554 false rejected as label 4334, true label 3203
# INFO:__main__:data id  1830 false rejected as label -1, true label 4243
# INFO:__main__:data id  1895 false rejected as label -1, true label 4552
# INFO:__main__:data id  1219 false rejected as label -1, true label 2508
# INFO:__main__:data id  239 false rejected as label -1, true label 386
# INFO:__main__:data id  1244 false rejected as label 4013, true label 2515
# INFO:__main__:data id  470 false rejected as label -1, true label 1208
# INFO:__main__:data id  891 false rejected as label -1, true label 1994
# INFO:__main__:data id  1751 false rejected as label -1, true label 3738
# INFO:__main__:data id  697 false rejected as label -1, true label 1893
# INFO:__main__:data id  957 false rejected as label -1, true label 2045
# INFO:__main__:data id  421 false rejected as label -1, true label 1048
# INFO:__main__:data id  141 false rejected as label -1, true label 305
# INFO:__main__:data id  1068 false rejected as label -1, true label 2277
# INFO:__main__:data id  1208 false rejected as label 224, true label 2508
# INFO:__main__:data id  850 false rejected as label 787, true label 1965
# INFO:__main__:data id  1672 false rejected as label -1, true label 3402
# INFO:__main__:data id  471 false rejected as label 4334, true label 1208
# INFO:__main__:data id  1146 false rejected as label -1, true label 2469
# INFO:__main__:data id  302 false rejected as label 2747, true label 532
# INFO:__main__:data id  903 false rejected as label -1, true label 2028
# INFO:__main__:data id  2137 false rejected as label -1, true label 5409
# INFO:__main__:data id  231 false rejected as label 374, true label 386
# INFO:__main__:data id  1324 false rejected as label -1, true label 2683
# INFO:__main__:data id  1061 false rejected as label -1, true label 2277
# INFO:__main__:data id  843 false rejected as label 386, true label 1965
# INFO:__main__:data id  2063 false rejected as label -1, true label 5040
# INFO:__main__:data id  1969 false rejected as label -1, true label 4837
# INFO:__main__:data id  2084 false rejected as label 4774, true label 5040
# INFO:__main__:data id  1722 false rejected as label -1, true label 3705
# INFO:__main__:data id  1333 false rejected as label 4573, true label 2683
# INFO:__main__:data id  2003 false rejected as label -1, true label 4868
# INFO:__main__:data id  670 false rejected as label -1, true label 1872
# INFO:__main__:data id  423 false rejected as label -1, true label 1048
# INFO:__main__:true_acceptance: 0.5126
# INFO:__main__:false_rejection: 0.4874
# INFO:__main__:Testing random draw labels...
# INFO:__main__:data id  0 false accepted as label 249, none autherized label 1330
# INFO:__main__:data id  1 false accepted as label 1934, none autherized label 297
# INFO:__main__:data id  2 rejected label 2890, none autherized
# INFO:__main__:data id  3 rejected label 3119, none autherized
# INFO:__main__:data id  4 rejected label 3110, none autherized
# INFO:__main__:data id  5 rejected label 5356, none autherized
# INFO:__main__:data id  6 rejected label 4452, none autherized
# INFO:__main__:data id  7 rejected label 681, none autherized
# INFO:__main__:data id  8 false accepted as label 3705, none autherized label 1107
# INFO:__main__:data id  9 rejected label 2106, none autherized
# INFO:__main__:data id  10 rejected label 2187, none autherized
# INFO:__main__:data id  11 rejected label 4212, none autherized
# INFO:__main__:data id  12 rejected label 332, none autherized
# INFO:__main__:data id  13 false accepted as label 374, none autherized label 3200
# INFO:__main__:data id  14 rejected label 475, none autherized
# INFO:__main__:data id  15 rejected label 4414, none autherized
# INFO:__main__:data id  16 rejected label 2307, none autherized
# INFO:__main__:data id  17 rejected label 1710, none autherized
# INFO:__main__:data id  18 rejected label 2663, none autherized
# INFO:__main__:data id  19 false accepted as label 1208, none autherized label 5138
# INFO:__main__:data id  20 rejected label 263, none autherized
# INFO:__main__:data id  21 rejected label 1960, none autherized
# INFO:__main__:data id  22 false accepted as label 4013, none autherized label 4917
# INFO:__main__:data id  23 false accepted as label 4964, none autherized label 2653
# INFO:__main__:data id  24 false accepted as label 3128, none autherized label 2557
# INFO:__main__:data id  25 rejected label 4012, none autherized
# INFO:__main__:data id  26 rejected label 5195, none autherized
# INFO:__main__:data id  27 rejected label 1515, none autherized
# INFO:__main__:data id  28 rejected label 2659, none autherized
# INFO:__main__:data id  29 false accepted as label 1994, none autherized label 1184
# INFO:__main__:data id  30 false accepted as label 3705, none autherized label 4354
# INFO:__main__:data id  31 rejected label 382, none autherized
# INFO:__main__:data id  32 false accepted as label 5355, none autherized label 3785
# INFO:__main__:data id  33 rejected label 4443, none autherized
# INFO:__main__:data id  34 false accepted as label 2289, none autherized label 2755
# INFO:__main__:data id  35 rejected label 1194, none autherized
# INFO:__main__:data id  36 rejected label 505, none autherized
# INFO:__main__:data id  37 rejected label 2099, none autherized
# INFO:__main__:data id  38 false accepted as label 4964, none autherized label 2115
# INFO:__main__:data id  39 rejected label 3230, none autherized
# INFO:__main__:data id  40 rejected label 1622, none autherized
# INFO:__main__:data id  41 rejected label 1274, none autherized
# INFO:__main__:data id  42 rejected label 4166, none autherized
# INFO:__main__:data id  43 false accepted as label 374, none autherized label 3979
# INFO:__main__:data id  44 false accepted as label 2847, none autherized label 349
# INFO:__main__:data id  45 rejected label 1393, none autherized
# INFO:__main__:data id  46 false accepted as label 3435, none autherized label 2838
# INFO:__main__:data id  47 rejected label 2592, none autherized
# INFO:__main__:data id  48 rejected label 1412, none autherized
# INFO:__main__:data id  49 false accepted as label 386, none autherized label 3071
# INFO:__main__:data id  50 rejected label 3587, none autherized
# INFO:__main__:data id  51 false accepted as label 3203, none autherized label 4093
# INFO:__main__:data id  52 rejected label 2135, none autherized
# INFO:__main__:data id  53 rejected label 4247, none autherized
# INFO:__main__:data id  54 rejected label 998, none autherized
# INFO:__main__:data id  55 rejected label 1126, none autherized
# INFO:__main__:data id  56 false accepted as label 4774, none autherized label 2705
# INFO:__main__:data id  57 false accepted as label 1208, none autherized label 1780
# INFO:__main__:data id  58 rejected label 2853, none autherized
# INFO:__main__:data id  59 rejected label 5695, none autherized
# INFO:__main__:data id  60 rejected label 3940, none autherized
# INFO:__main__:data id  61 false accepted as label 787, none autherized label 4496
# INFO:__main__:data id  62 false accepted as label 4868, none autherized label 3658
# INFO:__main__:data id  63 rejected label 434, none autherized
# INFO:__main__:data id  64 rejected label 1219, none autherized
# INFO:__main__:data id  65 rejected label 36, none autherized
# INFO:__main__:data id  66 false accepted as label 3128, none autherized label 5034
# INFO:__main__:data id  67 false accepted as label 305, none autherized label 445
# INFO:__main__:data id  68 false accepted as label 1405, none autherized label 2061
# INFO:__main__:data id  69 rejected label 444, none autherized
# INFO:__main__:data id  70 false accepted as label 1872, none autherized label 4769
# INFO:__main__:data id  71 false accepted as label 3328, none autherized label 2574
# INFO:__main__:data id  72 rejected label 3301, none autherized
# INFO:__main__:data id  73 false accepted as label 3203, none autherized label 4214
# INFO:__main__:data id  74 false accepted as label 4058, none autherized label 1589
# INFO:__main__:data id  75 rejected label 3379, none autherized
# INFO:__main__:data id  76 false accepted as label 4552, none autherized label 4393
# INFO:__main__:data id  77 rejected label 1929, none autherized
# INFO:__main__:data id  78 rejected label 3596, none autherized
# INFO:__main__:data id  79 rejected label 3893, none autherized
# INFO:__main__:data id  80 rejected label 502, none autherized
# INFO:__main__:data id  81 rejected label 1813, none autherized
# INFO:__main__:data id  82 rejected label 4130, none autherized
# INFO:__main__:data id  83 rejected label 4958, none autherized
# INFO:__main__:data id  84 rejected label 1312, none autherized
# INFO:__main__:data id  85 rejected label 3498, none autherized
# INFO:__main__:data id  86 rejected label 1440, none autherized
# INFO:__main__:data id  87 rejected label 2151, none autherized
# INFO:__main__:data id  88 false accepted as label 374, none autherized label 4727
# INFO:__main__:data id  89 false accepted as label 374, none autherized label 900
# INFO:__main__:data id  90 rejected label 2367, none autherized
# INFO:__main__:data id  91 false accepted as label 305, none autherized label 662
# INFO:__main__:data id  92 false accepted as label 3203, none autherized label 5478
# INFO:__main__:data id  93 false accepted as label 305, none autherized label 3285
# INFO:__main__:data id  94 rejected label 4525, none autherized
# INFO:__main__:data id  95 false accepted as label 5429, none autherized label 269
# INFO:__main__:data id  96 rejected label 106, none autherized
# INFO:__main__:data id  97 false accepted as label 2847, none autherized label 2029
# INFO:__main__:data id  98 rejected label 5501, none autherized
# INFO:__main__:data id  99 rejected label 1431, none autherized
# INFO:__main__:data id  100 rejected label 2194, none autherized
# INFO:__main__:data id  101 rejected label 934, none autherized
# INFO:__main__:data id  102 false accepted as label 5040, none autherized label 4148
# INFO:__main__:data id  103 rejected label 951, none autherized
# INFO:__main__:data id  104 rejected label 4636, none autherized
# INFO:__main__:data id  105 false accepted as label 3128, none autherized label 5689
# INFO:__main__:data id  106 rejected label 2853, none autherized
# INFO:__main__:data id  107 rejected label 1857, none autherized
# INFO:__main__:data id  108 rejected label 1767, none autherized
# INFO:__main__:data id  109 rejected label 696, none autherized
# INFO:__main__:data id  110 false accepted as label 2515, none autherized label 404
# INFO:__main__:data id  111 rejected label 2189, none autherized
# INFO:__main__:data id  112 false accepted as label 3435, none autherized label 5358
# INFO:__main__:data id  113 false accepted as label 4868, none autherized label 2806
# INFO:__main__:data id  114 false accepted as label 3435, none autherized label 1765
# INFO:__main__:data id  115 false accepted as label 4013, none autherized label 1105
# INFO:__main__:data id  116 rejected label 5539, none autherized
# INFO:__main__:data id  117 rejected label 5487, none autherized
# INFO:__main__:data id  118 rejected label 2113, none autherized
# INFO:__main__:data id  119 false accepted as label 1934, none autherized label 928
# INFO:__main__:data id  120 rejected label 1033, none autherized
# INFO:__main__:data id  121 rejected label 3383, none autherized
# INFO:__main__:data id  122 rejected label 1291, none autherized
# INFO:__main__:data id  123 rejected label 340, none autherized
# INFO:__main__:data id  124 rejected label 696, none autherized
# INFO:__main__:data id  125 rejected label 3697, none autherized
# INFO:__main__:data id  126 rejected label 3582, none autherized
# INFO:__main__:data id  127 false accepted as label 2277, none autherized label 870
# INFO:__main__:data id  128 rejected label 1579, none autherized
# INFO:__main__:data id  129 false accepted as label 5660, none autherized label 1662
# INFO:__main__:data id  130 false accepted as label 2508, none autherized label 217
# INFO:__main__:data id  131 rejected label 2708, none autherized
# INFO:__main__:data id  132 rejected label 3570, none autherized
# INFO:__main__:data id  133 false accepted as label 5355, none autherized label 5717
# INFO:__main__:data id  134 rejected label 5527, none autherized
# INFO:__main__:data id  135 rejected label 2354, none autherized
# INFO:__main__:data id  136 rejected label 202, none autherized
# INFO:__main__:data id  137 false accepted as label 4013, none autherized label 515
# INFO:__main__:data id  138 false accepted as label 224, none autherized label 1568
# INFO:__main__:data id  139 rejected label 4008, none autherized
# INFO:__main__:data id  140 rejected label 4991, none autherized
# INFO:__main__:data id  141 rejected label 3025, none autherized
# INFO:__main__:data id  142 rejected label 2903, none autherized
# INFO:__main__:data id  143 rejected label 4785, none autherized
# INFO:__main__:data id  144 false accepted as label 5570, none autherized label 1925
# INFO:__main__:data id  145 false accepted as label 418, none autherized label 247
# INFO:__main__:data id  146 false accepted as label 5355, none autherized label 3019
# INFO:__main__:data id  147 false accepted as label 5570, none autherized label 3943
# INFO:__main__:data id  148 rejected label 5072, none autherized
# INFO:__main__:data id  149 false accepted as label 224, none autherized label 2255
# INFO:__main__:data id  150 rejected label 4930, none autherized
# INFO:__main__:data id  151 rejected label 4154, none autherized
# INFO:__main__:data id  152 rejected label 4679, none autherized
# INFO:__main__:data id  153 rejected label 5223, none autherized
# INFO:__main__:data id  154 rejected label 873, none autherized
# INFO:__main__:data id  155 false accepted as label 4334, none autherized label 2864
# INFO:__main__:data id  156 false accepted as label 4573, none autherized label 3694
# INFO:__main__:data id  157 rejected label 3582, none autherized
# INFO:__main__:data id  158 rejected label 3513, none autherized
# INFO:__main__:data id  159 rejected label 1908, none autherized
# INFO:__main__:data id  160 rejected label 1159, none autherized
# INFO:__main__:data id  161 rejected label 828, none autherized
# INFO:__main__:data id  162 false accepted as label 1934, none autherized label 3270
# INFO:__main__:data id  163 rejected label 3399, none autherized
# INFO:__main__:data id  164 rejected label 1371, none autherized
# INFO:__main__:data id  165 rejected label 594, none autherized
# INFO:__main__:data id  166 false accepted as label 4013, none autherized label 5087
# INFO:__main__:data id  167 rejected label 296, none autherized
# INFO:__main__:data id  168 rejected label 3120, none autherized
# INFO:__main__:data id  169 rejected label 2745, none autherized
# INFO:__main__:data id  170 rejected label 2907, none autherized
# INFO:__main__:data id  171 false accepted as label 374, none autherized label 5684
# INFO:__main__:data id  172 rejected label 1155, none autherized
# INFO:__main__:data id  173 rejected label 3652, none autherized
# INFO:__main__:data id  174 rejected label 1213, none autherized
# INFO:__main__:data id  175 false accepted as label 249, none autherized label 4557
# INFO:__main__:data id  176 false accepted as label 418, none autherized label 2767
# INFO:__main__:data id  177 false accepted as label 2515, none autherized label 3323
# INFO:__main__:data id  178 rejected label 4125, none autherized
# INFO:__main__:data id  179 false accepted as label 2508, none autherized label 741
# INFO:__main__:data id  180 false accepted as label 2847, none autherized label 524
# INFO:__main__:data id  181 rejected label 3002, none autherized
# INFO:__main__:data id  182 false accepted as label 1208, none autherized label 408
# INFO:__main__:data id  183 rejected label 266, none autherized
# INFO:__main__:data id  184 rejected label 3984, none autherized
# INFO:__main__:data id  185 false accepted as label 2508, none autherized label 3314
# INFO:__main__:data id  186 false accepted as label 1208, none autherized label 4629
# INFO:__main__:data id  187 rejected label 2098, none autherized
# INFO:__main__:data id  188 rejected label 344, none autherized
# INFO:__main__:data id  189 false accepted as label 4013, none autherized label 2086
# INFO:__main__:data id  190 rejected label 1275, none autherized
# INFO:__main__:data id  191 rejected label 616, none autherized
# INFO:__main__:data id  192 rejected label 2871, none autherized
# INFO:__main__:data id  193 rejected label 4704, none autherized
# INFO:__main__:data id  194 rejected label 2699, none autherized
# INFO:__main__:data id  195 false accepted as label 2507, none autherized label 1343
# INFO:__main__:data id  196 rejected label 1652, none autherized
# INFO:__main__:data id  197 false accepted as label 3352, none autherized label 2268
# INFO:__main__:data id  198 rejected label 2805, none autherized
# INFO:__main__:data id  199 false accepted as label 1994, none autherized label 663
# INFO:__main__:true_rejection: 0.6350
# INFO:__main__:false_acceptance: 0.3650

# %%
clr.Alejandro_Toledo_match_visual()

# %%
clr.GW_Bush_Distance_visual()

# %% [markdown]
# Actually all Bush picture embeddings are pretty close to its anchor pictures.But side pictures(0.8874,0.5020) have larger distance than frontal pictures. This suggests that even within the same identity(supposedly only one cluster,we might have mini clusters. This would disturbe nearest neighbor matching.
